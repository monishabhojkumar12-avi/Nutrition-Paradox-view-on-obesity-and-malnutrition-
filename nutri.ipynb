# %% [markdown]
# <a href="https://colab.research.google.com/github/monishabhojkumar12-avi/Nutrition-Paradox-view-on-obesity-and-malnutrition-/blob/main/nutri.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import requests
import pprint



url = "https://ghoapi.azureedge.net/api/NCD_BMI_30C"

data = requests.get(url)
#print(data.json())

data
# Out:
# <Response [200]>

# %%
pprint.pprint(data.json())
# Out:
# Streaming output truncated to the last 5000 lines.
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_FMLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS18-PLUS',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 37.918562,
#             'Id': 10133857,
#             'IndicatorCode': 'NCD_BMI_30C',
#             'Low': 30.943134,
#             'NumericValue': 34.39894,
#             'ParentLocation': 'Americas',
#             'ParentLocationCode': 'AMR',
#             'SpatialDim': 'BRB',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2005,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2005-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2005-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2005',
#             'Value': '34.4 [30.9-37.9]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_MLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS18-PLUS',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 22.625428,
#             'Id': 10134172,
#             'IndicatorCode': 'NCD_BMI_30C',
#             'Low': 15.558814,
#             'NumericValue': 18.976489,
#             'ParentLocation': 'Americas',
#             'ParentLocationCode': 'AMR',
#             'SpatialDim': 'BOL',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2018,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2018-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2018-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2018',
#             'Value': '19.0 [15.6-22.6]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_MLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS18-PLUS',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 13.445076,
#             'Id': 10135563,
#             'IndicatorCode': 'NCD_BMI_30C',
#             'Low': 11.521526,
#             'NumericValue': 12.451769,
#             'ParentLocation': 'Africa',
#             'ParentLocationCode': 'AFR',
#             'SpatialDim': 'ZAF',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2010,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2010-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2010-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2010',
#             'Value': '12.5 [11.5-13.4]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_FMLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS18-PLUS',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 12.523627,
#             'Id': 10135666,
#             'IndicatorCode': 'NCD_BMI_30C',
#             'Low': 9.7799383,
#             'NumericValue': 11.114134,
#             'ParentLocation': 'Africa',
#             'ParentLocationCode': 'AFR',
#             'SpatialDim': 'BEN',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2016,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2016-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2016-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2016',
#             'Value': '11.1 [9.8-12.5]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-05-23T13:35:20.483+02:00',
#             'Dim1': 'SEX_MLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS18-PLUS',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 25.269112,
#             'Id': 10135836,
#             'IndicatorCode': 'NCD_BMI_30C',
#             'Low': 24.050105,
#             'NumericValue': 24.657683,
#             'ParentLocation': None,
#             'ParentLocationCode': None,
#             'SpatialDim': 'AMR',
#             'SpatialDimType': 'REGION',
#             'TimeDim': 2011,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2011-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2011-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2011',
#             'Value': '24.7 [24.1-25.3]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_BTSX',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS18-PLUS',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 4.209638,
#             'Id': 10136438,
#             'IndicatorCode': 'NCD_BMI_30C',
#             'Low': 3.0321358,
#             'NumericValue': 3.5889123,
#             'ParentLocation': 'Eastern Mediterranean',
#             'ParentLocationCode': 'EMR',
#             'SpatialDim': 'PAK',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 1994,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '1994-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '1994-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '1994',
#             'Value': '3.6 [3.0-4.2]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_FMLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS18-PLUS',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 26.568657,
#             'Id': 10136621,
#             'IndicatorCode': 'NCD_BMI_30C',
#             'Low': 18.112233,
#             'NumericValue': 22.235389,
#             'ParentLocation': 'Americas',
#             'ParentLocationCode': 'AMR',
#             'SpatialDim': 'LCA',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 1998,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '1998-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '1998-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '1998',
#             'Value': '22.2 [18.1-26.6]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_FMLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS18-PLUS',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 30.288529,
#             'Id': 10136683,
#             'IndicatorCode': 'NCD_BMI_30C',
#             'Low': 26.220962,
#             'NumericValue': 28.282961,
#             'ParentLocation': 'Americas',
#             'ParentLocationCode': 'AMR',
#             'SpatialDim': 'ARG',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2013,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2013-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2013-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2013',
#             'Value': '28.3 [26.2-30.3]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_BTSX',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS18-PLUS',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 31.100479,
#             'Id': 10136853,
#             'IndicatorCode': 'NCD_BMI_30C',
#             'Low': 23.633814,
#             'NumericValue': 27.214009,
#             'ParentLocation': 'Americas',
#             'ParentLocationCode': 'AMR',
#             'SpatialDim': 'GUY',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2021,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2021-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2021-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2021',
#             'Value': '27.2 [23.6-31.1]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_FMLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS18-PLUS',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 12.727639,
#             'Id': 10136943,
#             'IndicatorCode': 'NCD_BMI_30C',
#             'Low': 9.356539,
#             'NumericValue': 10.978277,
#             'ParentLocation': 'Europe',
#             'ParentLocationCode': 'EUR',
#             'SpatialDim': 'CHE',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2013,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2013-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2013-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2013',
#             'Value': '11.0 [9.4-12.7]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_MLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS18-PLUS',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 8.7774813,
#             'Id': 10137309,
#             'IndicatorCode': 'NCD_BMI_30C',
#             'Low': 3.8577139,
#             'NumericValue': 6.065999,
#             'ParentLocation': 'Africa',
#             'ParentLocationCode': 'AFR',
#             'SpatialDim': 'GAB',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2007,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2007-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2007-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2007',
#             'Value': '6.1 [3.9-8.8]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_BTSX',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS18-PLUS',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 5.4976527,
#             'Id': 10137629,
#             'IndicatorCode': 'NCD_BMI_30C',
#             'Low': 1.886956,
#             'NumericValue': 3.3539165,
#             'ParentLocation': 'Africa',
#             'ParentLocationCode': 'AFR',
#             'SpatialDim': 'AGO',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 1994,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '1994-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '1994-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '1994',
#             'Value': '3.4 [1.9-5.5]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_MLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS18-PLUS',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 31.223413,
#             'Id': 10137794,
#             'IndicatorCode': 'NCD_BMI_30C',
#             'Low': 25.84835,
#             'NumericValue': 28.512335,
#             'ParentLocation': 'Europe',
#             'ParentLocationCode': 'EUR',
#             'SpatialDim': 'HUN',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2012,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2012-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2012-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2012',
#             'Value': '28.5 [25.8-31.2]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_FMLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS18-PLUS',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 38.235041,
#             'Id': 10138155,
#             'IndicatorCode': 'NCD_BMI_30C',
#             'Low': 29.660198,
#             'NumericValue': 33.870724,
#             'ParentLocation': 'Europe',
#             'ParentLocationCode': 'EUR',
#             'SpatialDim': 'GRC',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2021,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2021-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2021-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2021',
#             'Value': '33.9 [29.7-38.2]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_MLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS18-PLUS',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 1.8316368,
#             'Id': 10138559,
#             'IndicatorCode': 'NCD_BMI_30C',
#             'Low': 0.66821757,
#             'NumericValue': 1.1527189,
#             'ParentLocation': 'Africa',
#             'ParentLocationCode': 'AFR',
#             'SpatialDim': 'TZA',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 1994,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '1994-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '1994-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '1994',
#             'Value': '1.2 [0.7-1.8]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_FMLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS18-PLUS',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 33.25792,
#             'Id': 10140402,
#             'IndicatorCode': 'NCD_BMI_30C',
#             'Low': 19.28539,
#             'NumericValue': 25.992942,
#             'ParentLocation': 'Americas',
#             'ParentLocationCode': 'AMR',
#             'SpatialDim': 'SUR',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2006,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2006-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2006-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2006',
#             'Value': '26.0 [19.3-33.3]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_MLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS18-PLUS',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 3.9465778,
#             'Id': 10140529,
#             'IndicatorCode': 'NCD_BMI_30C',
#             'Low': 0.58846311,
#             'NumericValue': 1.7756579,
#             'ParentLocation': 'Africa',
#             'ParentLocationCode': 'AFR',
#             'SpatialDim': 'GNB',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 1998,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '1998-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '1998-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '1998',
#             'Value': '1.8 [0.6-3.9]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_FMLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS18-PLUS',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 70.747328,
#             'Id': 10140635,
#             'IndicatorCode': 'NCD_BMI_30C',
#             'Low': 64.934522,
#             'NumericValue': 67.859018,
#             'ParentLocation': 'Western Pacific',
#             'ParentLocationCode': 'WPR',
#             'SpatialDim': 'NRU',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 1999,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '1999-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '1999-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '1999',
#             'Value': '67.9 [64.9-70.7]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_FMLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS18-PLUS',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 27.86622,
#             'Id': 10140962,
#             'IndicatorCode': 'NCD_BMI_30C',
#             'Low': 23.392454,
#             'NumericValue': 25.595871,
#             'ParentLocation': 'Americas',
#             'ParentLocationCode': 'AMR',
#             'SpatialDim': 'CAN',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2018,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2018-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2018-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2018',
#             'Value': '25.6 [23.4-27.9]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_BTSX',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS18-PLUS',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 13.968103,
#             'Id': 10141783,
#             'IndicatorCode': 'NCD_BMI_30C',
#             'Low': 10.45547,
#             'NumericValue': 12.130369,
#             'ParentLocation': 'Africa',
#             'ParentLocationCode': 'AFR',
#             'SpatialDim': 'GAB',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2008,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2008-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2008-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2008',
#             'Value': '12.1 [10.5-14.0]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_MLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS18-PLUS',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 1.6892845,
#             'Id': 10142934,
#             'IndicatorCode': 'NCD_BMI_30C',
#             'Low': 0.83289584,
#             'NumericValue': 1.211158,
#             'ParentLocation': 'Africa',
#             'ParentLocationCode': 'AFR',
#             'SpatialDim': 'MWI',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2008,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2008-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2008-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2008',
#             'Value': '1.2 [0.8-1.7]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_BTSX',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS18-PLUS',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 23.607571,
#             'Id': 10143025,
#             'IndicatorCode': 'NCD_BMI_30C',
#             'Low': 17.926879,
#             'NumericValue': 20.709397,
#             'ParentLocation': 'Eastern Mediterranean',
#             'ParentLocationCode': 'EMR',
#             'SpatialDim': 'ARE',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 1994,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '1994-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '1994-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '1994',
#             'Value': '20.7 [17.9-23.6]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_FMLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS18-PLUS',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 16.477989,
#             'Id': 10143199,
#             'IndicatorCode': 'NCD_BMI_30C',
#             'Low': 8.3651207,
#             'NumericValue': 12.126324,
#             'ParentLocation': 'Africa',
#             'ParentLocationCode': 'AFR',
#             'SpatialDim': 'COG',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2022,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2022-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2022-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2022',
#             'Value': '12.1 [8.4-16.5]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_FMLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS18-PLUS',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 15.026285,
#             'Id': 10143288,
#             'IndicatorCode': 'NCD_BMI_30C',
#             'Low': 10.182296,
#             'NumericValue': 12.462687,
#             'ParentLocation': 'Africa',
#             'ParentLocationCode': 'AFR',
#             'SpatialDim': 'GAB',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2000,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2000-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2000-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2000',
#             'Value': '12.5 [10.2-15.0]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_FMLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS18-PLUS',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 18.19731,
#             'Id': 10144448,
#             'IndicatorCode': 'NCD_BMI_30C',
#             'Low': 14.948028,
#             'NumericValue': 16.537058,
#             'ParentLocation': 'Europe',
#             'ParentLocationCode': 'EUR',
#             'SpatialDim': 'NLD',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2009,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2009-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2009-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2009',
#             'Value': '16.5 [14.9-18.2]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-05-23T13:35:20.483+02:00',
#             'Dim1': 'SEX_BTSX',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS18-PLUS',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 26.146474,
#             'Id': 10145592,
#             'IndicatorCode': 'NCD_BMI_30C',
#             'Low': 24.525441,
#             'NumericValue': 25.318432,
#             'ParentLocation': None,
#             'ParentLocationCode': None,
#             'SpatialDim': 'EMR',
#             'SpatialDimType': 'REGION',
#             'TimeDim': 2019,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2019-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2019-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2019',
#             'Value': '25.3 [24.5-26.1]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_MLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS18-PLUS',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 18.930638,
#             'Id': 10145919,
#             'IndicatorCode': 'NCD_BMI_30C',
#             'Low': 18.055697,
#             'NumericValue': 18.485342,
#             'ParentLocation': None,
#             'ParentLocationCode': None,
#             'SpatialDim': 'WB_HI',
#             'SpatialDimType': 'WORLDBANKINCOMEGROUP',
#             'TimeDim': 2003,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2003-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2003-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2003',
#             'Value': '18.5 [18.1-18.9]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_BTSX',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS18-PLUS',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 18.469502,
#             'Id': 10146724,
#             'IndicatorCode': 'NCD_BMI_30C',
#             'Low': 17.207798,
#             'NumericValue': 17.844184,
#             'ParentLocation': 'Americas',
#             'ParentLocationCode': 'AMR',
#             'SpatialDim': 'PER',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2012,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2012-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2012-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2012',
#             'Value': '17.8 [17.2-18.5]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_BTSX',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS18-PLUS',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 34.518304,
#             'Id': 10147483,
#             'IndicatorCode': 'NCD_BMI_30C',
#             'Low': 30.955574,
#             'NumericValue': 32.716137,
#             'ParentLocation': 'Americas',
#             'ParentLocationCode': 'AMR',
#             'SpatialDim': 'CHL',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2015,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2015-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2015-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2015',
#             'Value': '32.7 [31.0-34.5]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_BTSX',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS18-PLUS',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 55.780703,
#             'Id': 10147866,
#             'IndicatorCode': 'NCD_BMI_30C',
#             'Low': 49.74075,
#             'NumericValue': 52.710181,
#             'ParentLocation': 'Western Pacific',
#             'ParentLocationCode': 'WPR',
#             'SpatialDim': 'TON',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2002,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2002-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2002-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2002',
#             'Value': '52.7 [49.7-55.8]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_MLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS18-PLUS',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 31.35184,
#             'Id': 10148214,
#             'IndicatorCode': 'NCD_BMI_30C',
#             'Low': 11.522329,
#             'NumericValue': 20.550053,
#             'ParentLocation': 'Europe',
#             'ParentLocationCode': 'EUR',
#             'SpatialDim': 'MKD',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2010,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2010-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2010-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2010',
#             'Value': '20.6 [11.5-31.4]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_MLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS18-PLUS',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 8.5806988,
#             'Id': 10148462,
#             'IndicatorCode': 'NCD_BMI_30C',
#             'Low': 3.5858311,
#             'NumericValue': 5.7652276,
#             'ParentLocation': 'Europe',
#             'ParentLocationCode': 'EUR',
#             'SpatialDim': 'ARM',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 1993,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '1993-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '1993-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '1993',
#             'Value': '5.8 [3.6-8.6]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_FMLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS18-PLUS',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 36.956039,
#             'Id': 10148680,
#             'IndicatorCode': 'NCD_BMI_30C',
#             'Low': 21.531828,
#             'NumericValue': 28.974071,
#             'ParentLocation': 'Africa',
#             'ParentLocationCode': 'AFR',
#             'SpatialDim': 'GNQ',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2022,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2022-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2022-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2022',
#             'Value': '29.0 [21.5-37.0]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_BTSX',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS18-PLUS',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 17.328149,
#             'Id': 10149199,
#             'IndicatorCode': 'NCD_BMI_30C',
#             'Low': 13.176033,
#             'NumericValue': 15.190716,
#             'ParentLocation': 'Western Pacific',
#             'ParentLocationCode': 'WPR',
#             'SpatialDim': 'PNG',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2007,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2007-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2007-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2007',
#             'Value': '15.2 [13.2-17.3]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_FMLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS18-PLUS',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 13.808282,
#             'Id': 10149374,
#             'IndicatorCode': 'NCD_BMI_30C',
#             'Low': 8.9111149,
#             'NumericValue': 11.236704,
#             'ParentLocation': 'Africa',
#             'ParentLocationCode': 'AFR',
#             'SpatialDim': 'GAB',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 1998,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '1998-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '1998-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '1998',
#             'Value': '11.2 [8.9-13.8]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_FMLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS18-PLUS',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 16.64072,
#             'Id': 10149456,
#             'IndicatorCode': 'NCD_BMI_30C',
#             'Low': 9.1934592,
#             'NumericValue': 12.695985,
#             'ParentLocation': 'Americas',
#             'ParentLocationCode': 'AMR',
#             'SpatialDim': 'PAN',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 1991,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '1991-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '1991-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '1991',
#             'Value': '12.7 [9.2-16.6]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_BTSX',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS18-PLUS',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 19.542098,
#             'Id': 10150644,
#             'IndicatorCode': 'NCD_BMI_30C',
#             'Low': 14.545536,
#             'NumericValue': 16.920191,
#             'ParentLocation': 'Africa',
#             'ParentLocationCode': 'AFR',
#             'SpatialDim': 'MRT',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2016,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2016-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2016-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2016',
#             'Value': '16.9 [14.5-19.5]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_FMLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS18-PLUS',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 40.569276,
#             'Id': 10150715,
#             'IndicatorCode': 'NCD_BMI_30C',
#             'Low': 36.920992,
#             'NumericValue': 38.725549,
#             'ParentLocation': 'Eastern Mediterranean',
#             'ParentLocationCode': 'EMR',
#             'SpatialDim': 'JOR',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2017,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2017-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2017-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2017',
#             'Value': '38.7 [36.9-40.6]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_BTSX',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS18-PLUS',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 2.295677,
#             'Id': 10152201,
#             'IndicatorCode': 'NCD_BMI_30C',
#             'Low': 1.348613,
#             'NumericValue': 1.7737832,
#             'ParentLocation': 'South-East Asia',
#             'ParentLocationCode': 'SEAR',
#             'SpatialDim': 'TLS',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2019,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2019-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2019-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2019',
#             'Value': '1.8 [1.3-2.3]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_MLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS18-PLUS',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 16.371205,
#             'Id': 10152521,
#             'IndicatorCode': 'NCD_BMI_30C',
#             'Low': 12.120064,
#             'NumericValue': 14.169855,
#             'ParentLocation': 'Western Pacific',
#             'ParentLocationCode': 'WPR',
#             'SpatialDim': 'FJI',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2002,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2002-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2002-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2002',
#             'Value': '14.2 [12.1-16.4]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_MLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS18-PLUS',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 0.14332774,
#             'Id': 10152832,
#             'IndicatorCode': 'NCD_BMI_30C',
#             'Low': 0.075260369,
#             'NumericValue': 0.1056706,
#             'ParentLocation': 'Western Pacific',
#             'ParentLocationCode': 'WPR',
#             'SpatialDim': 'VNM',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 1995,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '1995-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '1995-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '1995',
#             'Value': '0.1 [0.1-0.1]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_MLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS18-PLUS',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 6.5015353,
#             'Id': 10153159,
#             'IndicatorCode': 'NCD_BMI_30C',
#             'Low': 4.4804994,
#             'NumericValue': 5.4493457,
#             'ParentLocation': 'Eastern Mediterranean',
#             'ParentLocationCode': 'EMR',
#             'SpatialDim': 'PAK',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2006,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2006-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2006-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2006',
#             'Value': '5.4 [4.5-6.5]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_FMLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS18-PLUS',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 28.314936,
#             'Id': 10154042,
#             'IndicatorCode': 'NCD_BMI_30C',
#             'Low': 22.75957,
#             'NumericValue': 25.466365,
#             'ParentLocation': 'Africa',
#             'ParentLocationCode': 'AFR',
#             'SpatialDim': 'SYC',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 1999,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '1999-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '1999-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '1999',
#             'Value': '25.5 [22.8-28.3]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_BTSX',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS18-PLUS',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 15.175147,
#             'Id': 10154116,
#             'IndicatorCode': 'NCD_BMI_30C',
#             'Low': 8.3505623,
#             'NumericValue': 11.489722,
#             'ParentLocation': 'Americas',
#             'ParentLocationCode': 'AMR',
#             'SpatialDim': 'GRD',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 1992,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '1992-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '1992-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '1992',
#             'Value': '11.5 [8.4-15.2]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_MLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS18-PLUS',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 5.9507374,
#             'Id': 10154390,
#             'IndicatorCode': 'NCD_BMI_30C',
#             'Low': 4.0632542,
#             'NumericValue': 4.9450595,
#             'ParentLocation': 'Africa',
#             'ParentLocationCode': 'AFR',
#             'SpatialDim': 'MUS',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 1993,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '1993-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '1993-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '1993',
#             'Value': '4.9 [4.1-6.0]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_BTSX',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS18-PLUS',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 44.727629,
#             'Id': 10157012,
#             'IndicatorCode': 'NCD_BMI_30C',
#             'Low': 40.071976,
#             'NumericValue': 42.36097,
#             'ParentLocation': 'Americas',
#             'ParentLocationCode': 'AMR',
#             'SpatialDim': 'USA',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2021,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2021-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2021-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2021',
#             'Value': '42.4 [40.1-44.7]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_FMLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS18-PLUS',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 16.582802,
#             'Id': 10157706,
#             'IndicatorCode': 'NCD_BMI_30C',
#             'Low': 13.483112,
#             'NumericValue': 14.98518,
#             'ParentLocation': 'Americas',
#             'ParentLocationCode': 'AMR',
#             'SpatialDim': 'GTM',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2001,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2001-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2001-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2001',
#             'Value': '15.0 [13.5-16.6]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_MLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS18-PLUS',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 10.880329,
#             'Id': 10158338,
#             'IndicatorCode': 'NCD_BMI_30C',
#             'Low': 6.0885001,
#             'NumericValue': 8.323393,
#             'ParentLocation': 'Europe',
#             'ParentLocationCode': 'EUR',
#             'SpatialDim': 'ARM',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2002,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2002-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2002-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2002',
#             'Value': '8.3 [6.1-10.9]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_BTSX',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS18-PLUS',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 9.5377602,
#             'Id': 10158581,
#             'IndicatorCode': 'NCD_BMI_30C',
#             'Low': 6.9923207,
#             'NumericValue': 8.2083978,
#             'ParentLocation': 'Americas',
#             'ParentLocationCode': 'AMR',
#             'SpatialDim': 'PER',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 1993,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '1993-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '1993-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '1993',
#             'Value': '8.2 [7.0-9.5]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_BTSX',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS18-PLUS',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 2.5036836,
#             'Id': 10158615,
#             'IndicatorCode': 'NCD_BMI_30C',
#             'Low': 1.9372607,
#             'NumericValue': 2.2133427,
#             'ParentLocation': 'Western Pacific',
#             'ParentLocationCode': 'WPR',
#             'SpatialDim': 'IDN',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 1998,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '1998-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '1998-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '1998',
#             'Value': '2.2 [1.9-2.5]'},
#            {'Comments': None,
#             'DataSourceDim': None,
# ...
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 2.9616315,
#             'Id': 10226570,
#             'IndicatorCode': 'NCD_BMI_30C',
#             'Low': 2.0599347,
#             'NumericValue': 2.48849,
#             'ParentLocation': 'South-East Asia',
#             'ParentLocationCode': 'SEAR',
#             'SpatialDim': 'THA',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 1997,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '1997-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '1997-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '1997',
#             'Value': '2.5 [2.1-3.0]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_BTSX',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS18-PLUS',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 7.5590439,
#             'Id': 10226989,
#             'IndicatorCode': 'NCD_BMI_30C',
#             'Low': 5.1913589,
#             'NumericValue': 6.3055485,
#             'ParentLocation': 'Africa',
#             'ParentLocationCode': 'AFR',
#             'SpatialDim': 'SLE',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2021,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2021-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2021-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2021',
#             'Value': '6.3 [5.2-7.6]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_MLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS18-PLUS',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 23.750553,
#             'Id': 10227091,
#             'IndicatorCode': 'NCD_BMI_30C',
#             'Low': 7.1528338,
#             'NumericValue': 14.220241,
#             'ParentLocation': 'Europe',
#             'ParentLocationCode': 'EUR',
#             'SpatialDim': 'MKD',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 1999,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '1999-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '1999-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '1999',
#             'Value': '14.2 [7.2-23.8]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_BTSX',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS18-PLUS',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 2.4183305,
#             'Id': 10227157,
#             'IndicatorCode': 'NCD_BMI_30C',
#             'Low': 1.4876955,
#             'NumericValue': 1.9119445,
#             'ParentLocation': 'Africa',
#             'ParentLocationCode': 'AFR',
#             'SpatialDim': 'COD',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 1999,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '1999-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '1999-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '1999',
#             'Value': '1.9 [1.5-2.4]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_MLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS18-PLUS',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 28.439811,
#             'Id': 10227932,
#             'IndicatorCode': 'NCD_BMI_30C',
#             'Low': 19.057865,
#             'NumericValue': 23.599331,
#             'ParentLocation': 'Eastern Mediterranean',
#             'ParentLocationCode': 'EMR',
#             'SpatialDim': 'LBY',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2015,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2015-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2015-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2015',
#             'Value': '23.6 [19.1-28.4]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_MLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS18-PLUS',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 19.354613,
#             'Id': 10228100,
#             'IndicatorCode': 'NCD_BMI_30C',
#             'Low': 15.526268,
#             'NumericValue': 17.403126,
#             'ParentLocation': 'Americas',
#             'ParentLocationCode': 'AMR',
#             'SpatialDim': 'DOM',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2013,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2013-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2013-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2013',
#             'Value': '17.4 [15.5-19.4]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_FMLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS18-PLUS',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 36.556402,
#             'Id': 10228105,
#             'IndicatorCode': 'NCD_BMI_30C',
#             'Low': 29.8053,
#             'NumericValue': 33.148465,
#             'ParentLocation': 'Europe',
#             'ParentLocationCode': 'EUR',
#             'SpatialDim': 'HUN',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2019,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2019-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2019-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2019',
#             'Value': '33.1 [29.8-36.6]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_BTSX',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS18-PLUS',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 17.339663,
#             'Id': 10228583,
#             'IndicatorCode': 'NCD_BMI_30C',
#             'Low': 10.571525,
#             'NumericValue': 13.687269,
#             'ParentLocation': 'Europe',
#             'ParentLocationCode': 'EUR',
#             'SpatialDim': 'LUX',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 1990,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '1990-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '1990-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '1990',
#             'Value': '13.7 [10.6-17.3]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_MLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS18-PLUS',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 1.067057,
#             'Id': 10228744,
#             'IndicatorCode': 'NCD_BMI_30C',
#             'Low': 0.39580567,
#             'NumericValue': 0.67358571,
#             'ParentLocation': 'Africa',
#             'ParentLocationCode': 'AFR',
#             'SpatialDim': 'ERI',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2000,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2000-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2000-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2000',
#             'Value': '0.7 [0.4-1.1]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_FMLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS18-PLUS',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 6.8313561,
#             'Id': 10228851,
#             'IndicatorCode': 'NCD_BMI_30C',
#             'Low': 5.7328172,
#             'NumericValue': 6.2658221,
#             'ParentLocation': 'Western Pacific',
#             'ParentLocationCode': 'WPR',
#             'SpatialDim': 'CHN',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2017,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2017-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2017-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2017',
#             'Value': '6.3 [5.7-6.8]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_BTSX',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS18-PLUS',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 7.7802904,
#             'Id': 10228936,
#             'IndicatorCode': 'NCD_BMI_30C',
#             'Low': 4.4218604,
#             'NumericValue': 5.9392665,
#             'ParentLocation': 'Africa',
#             'ParentLocationCode': 'AFR',
#             'SpatialDim': 'GAB',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 1993,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '1993-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '1993-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '1993',
#             'Value': '5.9 [4.4-7.8]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_MLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS18-PLUS',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 4.0495247,
#             'Id': 10229301,
#             'IndicatorCode': 'NCD_BMI_30C',
#             'Low': 1.4975462,
#             'NumericValue': 2.5623575,
#             'ParentLocation': 'Africa',
#             'ParentLocationCode': 'AFR',
#             'SpatialDim': 'GIN',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2007,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2007-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2007-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2007',
#             'Value': '2.6 [1.5-4.0]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_BTSX',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS18-PLUS',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 30.898288,
#             'Id': 10229937,
#             'IndicatorCode': 'NCD_BMI_30C',
#             'Low': 24.044071,
#             'NumericValue': 27.397758,
#             'ParentLocation': 'Europe',
#             'ParentLocationCode': 'EUR',
#             'SpatialDim': 'LTU',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2013,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2013-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2013-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2013',
#             'Value': '27.4 [24.0-30.9]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_BTSX',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS18-PLUS',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 15.933628,
#             'Id': 10230620,
#             'IndicatorCode': 'NCD_BMI_30C',
#             'Low': 12.098271,
#             'NumericValue': 13.950612,
#             'ParentLocation': 'Europe',
#             'ParentLocationCode': 'EUR',
#             'SpatialDim': 'ARM',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 1997,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '1997-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '1997-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '1997',
#             'Value': '14.0 [12.1-15.9]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_MLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS18-PLUS',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 1.7849624,
#             'Id': 10232037,
#             'IndicatorCode': 'NCD_BMI_30C',
#             'Low': 0.76717637,
#             'NumericValue': 1.2023285,
#             'ParentLocation': 'Africa',
#             'ParentLocationCode': 'AFR',
#             'SpatialDim': 'ERI',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2011,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2011-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2011-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2011',
#             'Value': '1.2 [0.8-1.8]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_MLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS18-PLUS',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 13.982071,
#             'Id': 10232153,
#             'IndicatorCode': 'NCD_BMI_30C',
#             'Low': 7.0932619,
#             'NumericValue': 10.207333,
#             'ParentLocation': 'Americas',
#             'ParentLocationCode': 'AMR',
#             'SpatialDim': 'VCT',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2003,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2003-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2003-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2003',
#             'Value': '10.2 [7.1-14.0]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_BTSX',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS18-PLUS',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 20.305818,
#             'Id': 10232248,
#             'IndicatorCode': 'NCD_BMI_30C',
#             'Low': 17.021045,
#             'NumericValue': 18.639244,
#             'ParentLocation': 'Eastern Mediterranean',
#             'ParentLocationCode': 'EMR',
#             'SpatialDim': 'TUN',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2007,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2007-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2007-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2007',
#             'Value': '18.6 [17.0-20.3]'}]}

# %%
import pandas as pd
obesity=[]
obesity=data.json()["value"]
df_obesity=pd.DataFrame(obesity)
df_obesity
# Out:
#             Id IndicatorCode        SpatialDimType SpatialDim TimeDimType  \
# 0      9414013   NCD_BMI_30C               COUNTRY        TUV        YEAR
# 1      9414356   NCD_BMI_30C               COUNTRY        URY        YEAR
# 2      9414556   NCD_BMI_30C               COUNTRY        ROU        YEAR
# 3      9416897   NCD_BMI_30C  WORLDBANKINCOMEGROUP      WB_LI        YEAR
# 4      9417033   NCD_BMI_30C               COUNTRY        BTN        YEAR
# ...        ...           ...                   ...        ...         ...
# 20785  9409937   NCD_BMI_30C               COUNTRY        MNG        YEAR
# 20786  9411138   NCD_BMI_30C               COUNTRY        SGP        YEAR
# 20787  9411715   NCD_BMI_30C               COUNTRY        MOZ        YEAR
# 20788  9412114   NCD_BMI_30C               COUNTRY        GNQ        YEAR
# 20789  9412733   NCD_BMI_30C               COUNTRY        RUS        YEAR
#
#       ParentLocationCode   ParentLocation Dim1Type  TimeDim      Dim1  ...  \
# 0                    WPR  Western Pacific      SEX     2013  SEX_BTSX  ...
# 1                    AMR         Americas      SEX     2017   SEX_MLE  ...
# 2                    EUR           Europe      SEX     1992  SEX_BTSX  ...
# 3                   None             None      SEX     2014   SEX_MLE  ...
# 4                   SEAR  South-East Asia      SEX     2009  SEX_FMLE  ...
# ...                  ...              ...      ...      ...       ...  ...
# 20785                WPR  Western Pacific      SEX     2020   SEX_MLE  ...
# 20786                WPR  Western Pacific      SEX     2016  SEX_BTSX  ...
# 20787                AFR           Africa      SEX     1993  SEX_BTSX  ...
# 20788                AFR           Africa      SEX     2009  SEX_FMLE  ...
# 20789                EUR           Europe      SEX     1995   SEX_MLE  ...
#
#       DataSourceDim             Value NumericValue        Low       High  \
# 0              None  58.9 [55.1-62.7]    58.917272  55.144393  62.697655
# 1              None  26.7 [22.3-31.3]    26.692086  22.315124  31.259042
# 2              None    9.4 [8.0-10.8]     9.369269   7.964395  10.820170
# 3              None     4.0 [3.5-4.5]     3.958217   3.519309   4.494559
# 4              None     7.0 [5.3-8.9]     6.955057   5.327675   8.909813
# ...             ...               ...          ...        ...        ...
# 20785          None  19.6 [16.4-22.9]    19.608790  16.427787  22.924481
# 20786          None   10.1 [9.0-11.3]    10.080034   8.987132  11.300758
# 20787          None     1.7 [1.3-2.2]     1.668885   1.251620   2.190279
# 20788          None  20.1 [16.4-24.2]    20.137341  16.354725  24.237090
# 20789          None    9.7 [9.0-10.4]     9.694488   8.965173  10.438904
#
#       Comments                           Date  TimeDimensionValue  \
# 0         None  2024-02-29T16:06:41.017+01:00                2013
# 1         None  2024-02-29T16:06:41.017+01:00                2017
# 2         None  2024-02-29T16:06:41.017+01:00                1992
# 3         None  2024-02-29T16:06:41.017+01:00                2014
# 4         None  2024-02-29T16:06:41.017+01:00                2009
# ...        ...                            ...                 ...
# 20785     None  2024-02-29T16:06:41.017+01:00                2020
# 20786     None  2024-02-29T16:06:41.017+01:00                2016
# 20787     None  2024-02-29T16:06:41.017+01:00                1993
# 20788     None  2024-02-29T16:06:41.017+01:00                2009
# 20789     None  2024-02-29T16:06:41.017+01:00                1995
#
#               TimeDimensionBegin           TimeDimensionEnd
# 0      2013-01-01T00:00:00+01:00  2013-12-31T00:00:00+01:00
# 1      2017-01-01T00:00:00+01:00  2017-12-31T00:00:00+01:00
# 2      1992-01-01T00:00:00+01:00  1992-12-31T00:00:00+01:00
# 3      2014-01-01T00:00:00+01:00  2014-12-31T00:00:00+01:00
# 4      2009-01-01T00:00:00+01:00  2009-12-31T00:00:00+01:00
# ...                          ...                        ...
# 20785  2020-01-01T00:00:00+01:00  2020-12-31T00:00:00+01:00
# 20786  2016-01-01T00:00:00+01:00  2016-12-31T00:00:00+01:00
# 20787  1993-01-01T00:00:00+01:00  1993-12-31T00:00:00+01:00
# 20788  2009-01-01T00:00:00+01:00  2009-12-31T00:00:00+01:00
# 20789  1995-01-01T00:00:00+01:00  1995-12-31T00:00:00+01:00
#
# [20790 rows x 25 columns]

# %%
import pandas as pd
import requests
import pprint



url = "https://ghoapi.azureedge.net/api/NCD_BMI_PLUS2C"

data = requests.get(url)
#print(data.json())

data
# Out:
# <Response [200]>

# %%
pprint.pprint(data.json())
# Out:
# Streaming output truncated to the last 5000 lines.
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_BTSX',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS05-19',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 19.635297,
#             'Id': 10197218,
#             'IndicatorCode': 'NCD_BMI_PLUS2C',
#             'Low': 13.110982,
#             'NumericValue': 16.182099,
#             'ParentLocation': 'Eastern Mediterranean',
#             'ParentLocationCode': 'EMR',
#             'SpatialDim': 'JOR',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2019,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2019-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2019-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2019',
#             'Value': '16.2 [13.1-19.6]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_FMLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS05-19',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 9.676981,
#             'Id': 10197262,
#             'IndicatorCode': 'NCD_BMI_PLUS2C',
#             'Low': 2.508432,
#             'NumericValue': 5.3818356,
#             'ParentLocation': 'Africa',
#             'ParentLocationCode': 'AFR',
#             'SpatialDim': 'LSO',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2017,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2017-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2017-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2017',
#             'Value': '5.4 [2.5-9.7]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_MLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS05-19',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 8.4654652,
#             'Id': 10197263,
#             'IndicatorCode': 'NCD_BMI_PLUS2C',
#             'Low': 5.011344,
#             'NumericValue': 6.6281594,
#             'ParentLocation': 'Europe',
#             'ParentLocationCode': 'EUR',
#             'SpatialDim': 'ALB',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2010,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2010-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2010-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2010',
#             'Value': '6.6 [5.0-8.5]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_FMLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS10-19',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 2.4876757,
#             'Id': 10197324,
#             'IndicatorCode': 'NCD_BMI_PLUS2C',
#             'Low': 0.88843135,
#             'NumericValue': 1.5491084,
#             'ParentLocation': 'Africa',
#             'ParentLocationCode': 'AFR',
#             'SpatialDim': 'GIN',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2011,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2011-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2011-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2011',
#             'Value': '1.5 [0.9-2.5]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_MLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS05-19',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 9.5962606,
#             'Id': 10197386,
#             'IndicatorCode': 'NCD_BMI_PLUS2C',
#             'Low': 5.3701375,
#             'NumericValue': 7.2956502,
#             'ParentLocation': 'Europe',
#             'ParentLocationCode': 'EUR',
#             'SpatialDim': 'DNK',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2021,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2021-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2021-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2021',
#             'Value': '7.3 [5.4-9.6]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_FMLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS10-19',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 9.2975385,
#             'Id': 10197552,
#             'IndicatorCode': 'NCD_BMI_PLUS2C',
#             'Low': 5.9002034,
#             'NumericValue': 7.5088441,
#             'ParentLocation': 'Europe',
#             'ParentLocationCode': 'EUR',
#             'SpatialDim': 'GRC',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2019,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2019-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2019-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2019',
#             'Value': '7.5 [5.9-9.3]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_FMLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS10-19',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 4.1141253,
#             'Id': 10197885,
#             'IndicatorCode': 'NCD_BMI_PLUS2C',
#             'Low': 3.1007785,
#             'NumericValue': 3.581766,
#             'ParentLocation': 'Western Pacific',
#             'ParentLocationCode': 'WPR',
#             'SpatialDim': 'KOR',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2008,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2008-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2008-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2008',
#             'Value': '3.6 [3.1-4.1]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_FMLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS10-19',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 21.564278,
#             'Id': 10197998,
#             'IndicatorCode': 'NCD_BMI_PLUS2C',
#             'Low': 16.801868,
#             'NumericValue': 19.101399,
#             'ParentLocation': 'Eastern Mediterranean',
#             'ParentLocationCode': 'EMR',
#             'SpatialDim': 'KWT',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2001,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2001-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2001-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2001',
#             'Value': '19.1 [16.8-21.6]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_BTSX',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS05-09',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 23.955037,
#             'Id': 10198142,
#             'IndicatorCode': 'NCD_BMI_PLUS2C',
#             'Low': 8.4875882,
#             'NumericValue': 15.43667,
#             'ParentLocation': 'South-East Asia',
#             'ParentLocationCode': 'SEAR',
#             'SpatialDim': 'MDV',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2022,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2022-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2022-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2022',
#             'Value': '15.4 [8.5-24.0]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_FMLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS05-19',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 2.2829816,
#             'Id': 10198625,
#             'IndicatorCode': 'NCD_BMI_PLUS2C',
#             'Low': 0.49853753,
#             'NumericValue': 1.0931242,
#             'ParentLocation': 'Africa',
#             'ParentLocationCode': 'AFR',
#             'SpatialDim': 'RWA',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2012,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2012-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2012-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2012',
#             'Value': '1.1 [0.5-2.3]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_MLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS10-19',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 14.540416,
#             'Id': 10198911,
#             'IndicatorCode': 'NCD_BMI_PLUS2C',
#             'Low': 7.3640816,
#             'NumericValue': 10.675798,
#             'ParentLocation': 'Eastern Mediterranean',
#             'ParentLocationCode': 'EMR',
#             'SpatialDim': 'BHR',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2000,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2000-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2000-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2000',
#             'Value': '10.7 [7.4-14.5]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_FMLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS05-09',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 2.4397705,
#             'Id': 10199660,
#             'IndicatorCode': 'NCD_BMI_PLUS2C',
#             'Low': 1.2080139,
#             'NumericValue': 1.7535904,
#             'ParentLocation': 'Africa',
#             'ParentLocationCode': 'AFR',
#             'SpatialDim': 'ZAF',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 1998,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '1998-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '1998-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '1998',
#             'Value': '1.8 [1.2-2.4]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_FMLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS05-19',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 3.88483,
#             'Id': 10199668,
#             'IndicatorCode': 'NCD_BMI_PLUS2C',
#             'Low': 0.37976778,
#             'NumericValue': 1.5151465,
#             'ParentLocation': 'Africa',
#             'ParentLocationCode': 'AFR',
#             'SpatialDim': 'STP',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 1998,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '1998-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '1998-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '1998',
#             'Value': '1.5 [0.4-3.9]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_FMLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS05-19',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 5.9822693,
#             'Id': 10199728,
#             'IndicatorCode': 'NCD_BMI_PLUS2C',
#             'Low': 0.43607759,
#             'NumericValue': 2.2215296,
#             'ParentLocation': 'Western Pacific',
#             'ParentLocationCode': 'WPR',
#             'SpatialDim': 'MNG',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 1990,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '1990-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '1990-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '1990',
#             'Value': '2.2 [0.4-6.0]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_BTSX',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS05-09',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 22.016241,
#             'Id': 10199763,
#             'IndicatorCode': 'NCD_BMI_PLUS2C',
#             'Low': 7.5531237,
#             'NumericValue': 14.096063,
#             'ParentLocation': 'Western Pacific',
#             'ParentLocationCode': 'WPR',
#             'SpatialDim': 'COK',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2003,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2003-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2003-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2003',
#             'Value': '14.1 [7.6-22.0]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_MLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS05-09',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 33.760649,
#             'Id': 10199917,
#             'IndicatorCode': 'NCD_BMI_PLUS2C',
#             'Low': 5.6967977,
#             'NumericValue': 17.74133,
#             'ParentLocation': 'Americas',
#             'ParentLocationCode': 'AMR',
#             'SpatialDim': 'LCA',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2011,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2011-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2011-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2011',
#             'Value': '17.7 [5.7-33.8]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_MLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS10-19',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 16.843806,
#             'Id': 10200076,
#             'IndicatorCode': 'NCD_BMI_PLUS2C',
#             'Low': 3.7856158,
#             'NumericValue': 9.0509303,
#             'ParentLocation': 'Americas',
#             'ParentLocationCode': 'AMR',
#             'SpatialDim': 'BHS',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 1999,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '1999-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '1999-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '1999',
#             'Value': '9.1 [3.8-16.8]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_MLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS05-09',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 11.536183,
#             'Id': 10200099,
#             'IndicatorCode': 'NCD_BMI_PLUS2C',
#             'Low': 10.241309,
#             'NumericValue': 10.887246,
#             'ParentLocation': None,
#             'ParentLocationCode': None,
#             'SpatialDim': 'WB_HI',
#             'SpatialDimType': 'WORLDBANKINCOMEGROUP',
#             'TimeDim': 1998,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '1998-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '1998-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '1998',
#             'Value': '10.9 [10.2-11.5]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_MLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS05-09',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 5.3294323,
#             'Id': 10200169,
#             'IndicatorCode': 'NCD_BMI_PLUS2C',
#             'Low': 1.3647374,
#             'NumericValue': 2.9220356,
#             'ParentLocation': 'Americas',
#             'ParentLocationCode': 'AMR',
#             'SpatialDim': 'COL',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 1994,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '1994-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '1994-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '1994',
#             'Value': '2.9 [1.4-5.3]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_MLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS05-09',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 35.562217,
#             'Id': 10200306,
#             'IndicatorCode': 'NCD_BMI_PLUS2C',
#             'Low': 8.9434341,
#             'NumericValue': 20.957386,
#             'ParentLocation': 'Western Pacific',
#             'ParentLocationCode': 'WPR',
#             'SpatialDim': 'NRU',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2005,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2005-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2005-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2005',
#             'Value': '21.0 [8.9-35.6]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_MLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS05-09',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 9.5601246,
#             'Id': 10200870,
#             'IndicatorCode': 'NCD_BMI_PLUS2C',
#             'Low': 0.26631309,
#             'NumericValue': 2.8017791,
#             'ParentLocation': 'Africa',
#             'ParentLocationCode': 'AFR',
#             'SpatialDim': 'BEN',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2003,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2003-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2003-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2003',
#             'Value': '2.8 [0.3-9.6]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_MLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS10-19',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 1.194588,
#             'Id': 10200879,
#             'IndicatorCode': 'NCD_BMI_PLUS2C',
#             'Low': 0.14763317,
#             'NumericValue': 0.51589389,
#             'ParentLocation': 'Africa',
#             'ParentLocationCode': 'AFR',
#             'SpatialDim': 'CMR',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2002,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2002-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2002-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2002',
#             'Value': '0.5 [0.1-1.2]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_BTSX',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS05-19',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 21.307267,
#             'Id': 10201107,
#             'IndicatorCode': 'NCD_BMI_PLUS2C',
#             'Low': 8.7422118,
#             'NumericValue': 14.53729,
#             'ParentLocation': 'Western Pacific',
#             'ParentLocationCode': 'WPR',
#             'SpatialDim': 'TKL',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 1997,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '1997-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '1997-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '1997',
#             'Value': '14.5 [8.7-21.3]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_MLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS05-19',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 11.986837,
#             'Id': 10201374,
#             'IndicatorCode': 'NCD_BMI_PLUS2C',
#             'Low': 8.536686,
#             'NumericValue': 10.149325,
#             'ParentLocation': 'Western Pacific',
#             'ParentLocationCode': 'WPR',
#             'SpatialDim': 'MYS',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2004,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2004-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2004-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2004',
#             'Value': '10.1 [8.5-12.0]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_FMLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS10-19',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 5.3711567,
#             'Id': 10201591,
#             'IndicatorCode': 'NCD_BMI_PLUS2C',
#             'Low': 1.6604742,
#             'NumericValue': 3.1035965,
#             'ParentLocation': 'Europe',
#             'ParentLocationCode': 'EUR',
#             'SpatialDim': 'LVA',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2016,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2016-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2016-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2016',
#             'Value': '3.1 [1.7-5.4]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_FMLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS10-19',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 1.530399,
#             'Id': 10201616,
#             'IndicatorCode': 'NCD_BMI_PLUS2C',
#             'Low': 0.44729109,
#             'NumericValue': 0.8872089,
#             'ParentLocation': 'Eastern Mediterranean',
#             'ParentLocationCode': 'EMR',
#             'SpatialDim': 'PAK',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2003,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2003-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2003-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2003',
#             'Value': '0.9 [0.4-1.5]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_MLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS05-19',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 18.026263,
#             'Id': 10201738,
#             'IndicatorCode': 'NCD_BMI_PLUS2C',
#             'Low': 3.2916792,
#             'NumericValue': 9.3885243,
#             'ParentLocation': 'Europe',
#             'ParentLocationCode': 'EUR',
#             'SpatialDim': 'BLR',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2018,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2018-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2018-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2018',
#             'Value': '9.4 [3.3-18.0]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_BTSX',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS05-09',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 11.270894,
#             'Id': 10202054,
#             'IndicatorCode': 'NCD_BMI_PLUS2C',
#             'Low': 10.079826,
#             'NumericValue': 10.658862,
#             'ParentLocation': 'Europe',
#             'ParentLocationCode': 'EUR',
#             'SpatialDim': 'GBR',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2006,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2006-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2006-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2006',
#             'Value': '10.7 [10.1-11.3]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_FMLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS05-09',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 1.2533456,
#             'Id': 10202071,
#             'IndicatorCode': 'NCD_BMI_PLUS2C',
#             'Low': 0.7604504,
#             'NumericValue': 0.98861698,
#             'ParentLocation': 'South-East Asia',
#             'ParentLocationCode': 'SEAR',
#             'SpatialDim': 'IND',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2004,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2004-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2004-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2004',
#             'Value': '1.0 [0.8-1.3]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_FMLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS10-19',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 8.3153673,
#             'Id': 10202197,
#             'IndicatorCode': 'NCD_BMI_PLUS2C',
#             'Low': 5.7215013,
#             'NumericValue': 6.9533363,
#             'ParentLocation': 'Europe',
#             'ParentLocationCode': 'EUR',
#             'SpatialDim': 'ISR',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2012,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2012-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2012-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2012',
#             'Value': '7.0 [5.7-8.3]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_BTSX',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS05-09',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 7.5165786,
#             'Id': 10202454,
#             'IndicatorCode': 'NCD_BMI_PLUS2C',
#             'Low': 4.7057569,
#             'NumericValue': 5.9927139,
#             'ParentLocation': 'Europe',
#             'ParentLocationCode': 'EUR',
#             'SpatialDim': 'BEL',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2005,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2005-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2005-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2005',
#             'Value': '6.0 [4.7-7.5]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_MLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS05-19',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 9.3416914,
#             'Id': 10202487,
#             'IndicatorCode': 'NCD_BMI_PLUS2C',
#             'Low': 2.4864895,
#             'NumericValue': 5.3637058,
#             'ParentLocation': 'Eastern Mediterranean',
#             'ParentLocationCode': 'EMR',
#             'SpatialDim': 'MAR',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2013,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2013-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2013-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2013',
#             'Value': '5.4 [2.5-9.3]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_FMLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS05-09',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 6.5290563,
#             'Id': 10202534,
#             'IndicatorCode': 'NCD_BMI_PLUS2C',
#             'Low': 2.5174478,
#             'NumericValue': 4.2637713,
#             'ParentLocation': 'Europe',
#             'ParentLocationCode': 'EUR',
#             'SpatialDim': 'AUT',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 1999,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '1999-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '1999-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '1999',
#             'Value': '4.3 [2.5-6.5]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_BTSX',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS05-09',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 13.612145,
#             'Id': 10202786,
#             'IndicatorCode': 'NCD_BMI_PLUS2C',
#             'Low': 9.5775165,
#             'NumericValue': 11.515263,
#             'ParentLocation': 'Europe',
#             'ParentLocationCode': 'EUR',
#             'SpatialDim': 'GBR',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2022,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2022-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2022-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2022',
#             'Value': '11.5 [9.6-13.6]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_FMLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS05-19',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 9.8483659,
#             'Id': 10202822,
#             'IndicatorCode': 'NCD_BMI_PLUS2C',
#             'Low': 6.9838621,
#             'NumericValue': 8.3552517,
#             'ParentLocation': 'Europe',
#             'ParentLocationCode': 'EUR',
#             'SpatialDim': 'HUN',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2013,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2013-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2013-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2013',
#             'Value': '8.4 [7.0-9.8]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_FMLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS10-19',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 8.986073,
#             'Id': 10202848,
#             'IndicatorCode': 'NCD_BMI_PLUS2C',
#             'Low': 5.3097934,
#             'NumericValue': 7.0235915,
#             'ParentLocation': 'Europe',
#             'ParentLocationCode': 'EUR',
#             'SpatialDim': 'CHE',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2019,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2019-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2019-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2019',
#             'Value': '7.0 [5.3-9.0]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_BTSX',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS10-19',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 6.5612867,
#             'Id': 10202875,
#             'IndicatorCode': 'NCD_BMI_PLUS2C',
#             'Low': 4.1140798,
#             'NumericValue': 5.2640602,
#             'ParentLocation': 'Americas',
#             'ParentLocationCode': 'AMR',
#             'SpatialDim': 'GTM',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2007,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2007-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2007-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2007',
#             'Value': '5.3 [4.1-6.6]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_FMLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS05-09',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 7.1926847,
#             'Id': 10203165,
#             'IndicatorCode': 'NCD_BMI_PLUS2C',
#             'Low': 4.5222878,
#             'NumericValue': 5.773516,
#             'ParentLocation': 'Americas',
#             'ParentLocationCode': 'AMR',
#             'SpatialDim': 'PER',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2005,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2005-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2005-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2005',
#             'Value': '5.8 [4.5-7.2]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_FMLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS05-09',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 15.036036,
#             'Id': 10203470,
#             'IndicatorCode': 'NCD_BMI_PLUS2C',
#             'Low': 2.5007673,
#             'NumericValue': 7.2514169,
#             'ParentLocation': 'Americas',
#             'ParentLocationCode': 'AMR',
#             'SpatialDim': 'GUY',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2009,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2009-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2009-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2009',
#             'Value': '7.3 [2.5-15.0]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_FMLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS10-19',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 1.7168168,
#             'Id': 10203471,
#             'IndicatorCode': 'NCD_BMI_PLUS2C',
#             'Low': 0.57404987,
#             'NumericValue': 1.0565139,
#             'ParentLocation': 'Europe',
#             'ParentLocationCode': 'EUR',
#             'SpatialDim': 'TJK',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2009,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2009-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2009-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2009',
#             'Value': '1.1 [0.6-1.7]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_MLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS05-09',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 11.908239,
#             'Id': 10203511,
#             'IndicatorCode': 'NCD_BMI_PLUS2C',
#             'Low': 0.52847648,
#             'NumericValue': 4.0856291,
#             'ParentLocation': 'Europe',
#             'ParentLocationCode': 'EUR',
#             'SpatialDim': 'AZE',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 1995,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '1995-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '1995-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '1995',
#             'Value': '4.1 [0.5-11.9]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_BTSX',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS05-19',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 7.1154021,
#             'Id': 10203542,
#             'IndicatorCode': 'NCD_BMI_PLUS2C',
#             'Low': 1.1916191,
#             'NumericValue': 3.4311719,
#             'ParentLocation': 'Western Pacific',
#             'ParentLocationCode': 'WPR',
#             'SpatialDim': 'KHM',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2012,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2012-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2012-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2012',
#             'Value': '3.4 [1.2-7.1]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_BTSX',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS05-19',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 2.588108,
#             'Id': 10203638,
#             'IndicatorCode': 'NCD_BMI_PLUS2C',
#             'Low': 0.6977031,
#             'NumericValue': 1.4059608,
#             'ParentLocation': 'Africa',
#             'ParentLocationCode': 'AFR',
#             'SpatialDim': 'ZWE',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2007,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2007-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2007-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2007',
#             'Value': '1.4 [0.7-2.6]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_FMLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS05-19',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 22.008102,
#             'Id': 10204244,
#             'IndicatorCode': 'NCD_BMI_PLUS2C',
#             'Low': 10.050354,
#             'NumericValue': 15.57546,
#             'ParentLocation': 'Americas',
#             'ParentLocationCode': 'AMR',
#             'SpatialDim': 'VCT',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2012,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2012-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2012-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2012',
#             'Value': '15.6 [10.1-22.0]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_BTSX',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS10-19',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 8.0363296,
#             'Id': 10204397,
#             'IndicatorCode': 'NCD_BMI_PLUS2C',
#             'Low': 4.9477588,
#             'NumericValue': 6.4168669,
#             'ParentLocation': 'Americas',
#             'ParentLocationCode': 'AMR',
#             'SpatialDim': 'BOL',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2009,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2009-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2009-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2009',
#             'Value': '6.4 [4.9-8.0]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_BTSX',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS10-19',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 2.7545132,
#             'Id': 10204426,
#             'IndicatorCode': 'NCD_BMI_PLUS2C',
#             'Low': 0.29083632,
#             'NumericValue': 1.1129204,
#             'ParentLocation': 'Africa',
#             'ParentLocationCode': 'AFR',
#             'SpatialDim': 'SSD',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2000,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2000-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2000-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2000',
#             'Value': '1.1 [0.3-2.8]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_FMLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS10-19',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 3.496822,
#             'Id': 10204522,
#             'IndicatorCode': 'NCD_BMI_PLUS2C',
#             'Low': 1.4727163,
#             'NumericValue': 2.3487099,
#             'ParentLocation': 'Africa',
#             'ParentLocationCode': 'AFR',
#             'SpatialDim': 'BEN',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2008,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2008-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2008-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2008',
#             'Value': '2.3 [1.5-3.5]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_BTSX',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS10-19',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 20.653957,
#             'Id': 10204733,
#             'IndicatorCode': 'NCD_BMI_PLUS2C',
#             'Low': 13.38858,
#             'NumericValue': 16.854534,
#             'ParentLocation': 'Western Pacific',
#             'ParentLocationCode': 'WPR',
#             'SpatialDim': 'PLW',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2004,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2004-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2004-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2004',
#             'Value': '16.9 [13.4-20.7]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_MLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS05-09',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 13.727415,
#             'Id': 10204748,
#             'IndicatorCode': 'NCD_BMI_PLUS2C',
#             'Low': 10.226385,
#             'NumericValue': 11.898727,
#             'ParentLocation': 'Europe',
#             'ParentLocationCode': 'EUR',
#             'SpatialDim': 'POL',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2010,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2010-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2010-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2010',
#             'Value': '11.9 [10.2-13.7]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_BTSX',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS10-19',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 3.8309056,
#             'Id': 10204777,
#             'IndicatorCode': 'NCD_BMI_PLUS2C',
#             'Low': 0.68637161,
#             'NumericValue': 1.8492924,
#             'ParentLocation': 'Europe',
#             'ParentLocationCode': 'EUR',
#             'SpatialDim': 'LTU',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 1990,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '1990-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '1990-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '1990',
#             'Value': '1.8 [0.7-3.8]'},
#            {'Comments': None,
# ...
#             'Dim3Type': None,
#             'High': 3.6578804,
#             'Id': 10229855,
#             'IndicatorCode': 'NCD_BMI_PLUS2C',
#             'Low': 1.8287348,
#             'NumericValue': 2.6003314,
#             'ParentLocation': None,
#             'ParentLocationCode': None,
#             'SpatialDim': 'WB_LI',
#             'SpatialDimType': 'WORLDBANKINCOMEGROUP',
#             'TimeDim': 2007,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2007-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2007-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2007',
#             'Value': '2.6 [1.8-3.7]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_FMLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS05-19',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 2.6859995,
#             'Id': 10229928,
#             'IndicatorCode': 'NCD_BMI_PLUS2C',
#             'Low': 0.21455011,
#             'NumericValue': 0.99885054,
#             'ParentLocation': 'Eastern Mediterranean',
#             'ParentLocationCode': 'EMR',
#             'SpatialDim': 'AFG',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 1996,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '1996-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '1996-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '1996',
#             'Value': '1.0 [0.2-2.7]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_BTSX',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS05-09',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 15.702224,
#             'Id': 10230018,
#             'IndicatorCode': 'NCD_BMI_PLUS2C',
#             'Low': 9.0776898,
#             'NumericValue': 12.160808,
#             'ParentLocation': 'Eastern Mediterranean',
#             'ParentLocationCode': 'EMR',
#             'SpatialDim': 'BHR',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2008,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2008-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2008-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2008',
#             'Value': '12.2 [9.1-15.7]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_BTSX',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS05-09',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 8.7948166,
#             'Id': 10230172,
#             'IndicatorCode': 'NCD_BMI_PLUS2C',
#             'Low': 3.05,
#             'NumericValue': 5.4675583,
#             'ParentLocation': 'Americas',
#             'ParentLocationCode': 'AMR',
#             'SpatialDim': 'ARG',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 1995,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '1995-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '1995-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '1995',
#             'Value': '5.5 [3.1-8.8]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_MLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS05-09',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 12.391895,
#             'Id': 10230611,
#             'IndicatorCode': 'NCD_BMI_PLUS2C',
#             'Low': 6.5657362,
#             'NumericValue': 9.2680022,
#             'ParentLocation': 'Americas',
#             'ParentLocationCode': 'AMR',
#             'SpatialDim': 'PAN',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2002,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2002-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2002-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2002',
#             'Value': '9.3 [6.6-12.4]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_MLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS05-19',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 34.877816,
#             'Id': 10230817,
#             'IndicatorCode': 'NCD_BMI_PLUS2C',
#             'Low': 3.3258993,
#             'NumericValue': 16.634887,
#             'ParentLocation': 'Western Pacific',
#             'ParentLocationCode': 'WPR',
#             'SpatialDim': 'VUT',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2021,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2021-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2021-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2021',
#             'Value': '16.6 [3.3-34.9]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_MLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS10-19',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 6.1100427,
#             'Id': 10231026,
#             'IndicatorCode': 'NCD_BMI_PLUS2C',
#             'Low': 1.2304069,
#             'NumericValue': 3.1704932,
#             'ParentLocation': 'Americas',
#             'ParentLocationCode': 'AMR',
#             'SpatialDim': 'GTM',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 1994,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '1994-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '1994-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '1994',
#             'Value': '3.2 [1.2-6.1]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_BTSX',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS10-19',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 13.448733,
#             'Id': 10231259,
#             'IndicatorCode': 'NCD_BMI_PLUS2C',
#             'Low': 9.1541216,
#             'NumericValue': 11.196404,
#             'ParentLocation': 'Europe',
#             'ParentLocationCode': 'EUR',
#             'SpatialDim': 'CYP',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2008,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2008-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2008-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2008',
#             'Value': '11.2 [9.2-13.4]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_MLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS05-19',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 6.3411847,
#             'Id': 10231294,
#             'IndicatorCode': 'NCD_BMI_PLUS2C',
#             'Low': 0.23648054,
#             'NumericValue': 2.0321887,
#             'ParentLocation': 'Africa',
#             'ParentLocationCode': 'AFR',
#             'SpatialDim': 'MDG',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2014,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2014-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2014-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2014',
#             'Value': '2.0 [0.2-6.3]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_FMLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS10-19',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 4.3390919,
#             'Id': 10231368,
#             'IndicatorCode': 'NCD_BMI_PLUS2C',
#             'Low': 1.5734989,
#             'NumericValue': 2.7067091,
#             'ParentLocation': 'Europe',
#             'ParentLocationCode': 'EUR',
#             'SpatialDim': 'LTU',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2008,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2008-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2008-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2008',
#             'Value': '2.7 [1.6-4.3]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_MLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS05-09',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 18.564641,
#             'Id': 10231705,
#             'IndicatorCode': 'NCD_BMI_PLUS2C',
#             'Low': 1.2565847,
#             'NumericValue': 7.0820376,
#             'ParentLocation': 'Europe',
#             'ParentLocationCode': 'EUR',
#             'SpatialDim': 'ISL',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2001,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2001-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2001-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2001',
#             'Value': '7.1 [1.3-18.6]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_MLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS05-19',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 12.760153,
#             'Id': 10231807,
#             'IndicatorCode': 'NCD_BMI_PLUS2C',
#             'Low': 10.08785,
#             'NumericValue': 11.390631,
#             'ParentLocation': 'Europe',
#             'ParentLocationCode': 'EUR',
#             'SpatialDim': 'FIN',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2017,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2017-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2017-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2017',
#             'Value': '11.4 [10.1-12.8]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_BTSX',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS10-19',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 7.0062451,
#             'Id': 10231832,
#             'IndicatorCode': 'NCD_BMI_PLUS2C',
#             'Low': 3.437404,
#             'NumericValue': 5.0514854,
#             'ParentLocation': 'Europe',
#             'ParentLocationCode': 'EUR',
#             'SpatialDim': 'BEL',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 1997,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '1997-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '1997-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '1997',
#             'Value': '5.1 [3.4-7.0]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_BTSX',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS10-19',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 3.3851579,
#             'Id': 10232073,
#             'IndicatorCode': 'NCD_BMI_PLUS2C',
#             'Low': 0.69364011,
#             'NumericValue': 1.7150899,
#             'ParentLocation': 'Eastern Mediterranean',
#             'ParentLocationCode': 'EMR',
#             'SpatialDim': 'SDN',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2006,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2006-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2006-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2006',
#             'Value': '1.7 [0.7-3.4]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_BTSX',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS05-09',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 5.0042,
#             'Id': 10232431,
#             'IndicatorCode': 'NCD_BMI_PLUS2C',
#             'Low': 0.35935307,
#             'NumericValue': 1.8424215,
#             'ParentLocation': 'Africa',
#             'ParentLocationCode': 'AFR',
#             'SpatialDim': 'CPV',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2000,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2000-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2000-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2000',
#             'Value': '1.8 [0.4-5.0]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_MLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS05-09',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 12.270057,
#             'Id': 10232465,
#             'IndicatorCode': 'NCD_BMI_PLUS2C',
#             'Low': 0.92881331,
#             'NumericValue': 4.6810221,
#             'ParentLocation': 'Africa',
#             'ParentLocationCode': 'AFR',
#             'SpatialDim': 'STP',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2005,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2005-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2005-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2005',
#             'Value': '4.7 [0.9-12.3]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_MLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS05-19',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 2.187117,
#             'Id': 10232700,
#             'IndicatorCode': 'NCD_BMI_PLUS2C',
#             'Low': 0.14541603,
#             'NumericValue': 0.76168384,
#             'ParentLocation': 'South-East Asia',
#             'ParentLocationCode': 'SEAR',
#             'SpatialDim': 'BGD',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2006,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2006-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2006-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2006',
#             'Value': '0.8 [0.1-2.2]'}]}

# %%
import pandas as pd
obesity2=[]
obesity2=data.json()["value"]
df_obesity2=pd.DataFrame(obesity2)
df_obesity2
# Out:
#             Id   IndicatorCode SpatialDimType SpatialDim TimeDimType  \
# 0      9413284  NCD_BMI_PLUS2C        COUNTRY        SVN        YEAR
# 1      9413290  NCD_BMI_PLUS2C        COUNTRY        COM        YEAR
# 2      9413361  NCD_BMI_PLUS2C        COUNTRY        SGP        YEAR
# 3      9413397  NCD_BMI_PLUS2C        COUNTRY        IDN        YEAR
# 4      9413445  NCD_BMI_PLUS2C        COUNTRY        LKA        YEAR
# ...        ...             ...            ...        ...         ...
# 62365  9412346  NCD_BMI_PLUS2C        COUNTRY        PRY        YEAR
# 62366  9412408  NCD_BMI_PLUS2C        COUNTRY        HND        YEAR
# 62367  9412942  NCD_BMI_PLUS2C        COUNTRY        PLW        YEAR
# 62368  9413097  NCD_BMI_PLUS2C        COUNTRY        BHR        YEAR
# 62369  9413206  NCD_BMI_PLUS2C        COUNTRY        JOR        YEAR
#
#       ParentLocationCode         ParentLocation Dim1Type      Dim1  TimeDim  \
# 0                    EUR                 Europe      SEX   SEX_MLE     2006
# 1                    AFR                 Africa      SEX  SEX_FMLE     2017
# 2                    WPR        Western Pacific      SEX   SEX_MLE     2020
# 3                    WPR        Western Pacific      SEX  SEX_BTSX     1995
# 4                   SEAR        South-East Asia      SEX  SEX_BTSX     2003
# ...                  ...                    ...      ...       ...      ...
# 62365                AMR               Americas      SEX   SEX_MLE     1996
# 62366                AMR               Americas      SEX   SEX_MLE     2006
# 62367                WPR        Western Pacific      SEX  SEX_BTSX     2009
# 62368                EMR  Eastern Mediterranean      SEX   SEX_MLE     2014
# 62369                EMR  Eastern Mediterranean      SEX  SEX_FMLE     2018
#
#        ... DataSourceDim             Value NumericValue        Low       High  \
# 0      ...          None     8.9 [8.1-9.7]     8.887266   8.099298   9.692913
# 1      ...          None    5.1 [1.2-12.6]     5.081482   1.154804  12.616070
# 2      ...          None   23.7 [8.7-40.5]    23.749757   8.726980  40.513217
# 3      ...          None     2.0 [1.6-2.6]     2.039700   1.578857   2.570618
# 4      ...          None     1.7 [0.9-2.9]     1.669647   0.852432   2.920911
# ...    ...           ...               ...          ...        ...        ...
# 62365  ...          None    5.4 [1.5-12.2]     5.424515   1.453240  12.203929
# 62366  ...          None    7.4 [1.8-17.1]     7.378158   1.794300  17.109506
# 62367  ...          None  19.1 [16.9-21.4]    19.078273  16.929306  21.377192
# 62368  ...          None  16.7 [11.3-22.9]    16.665152  11.322826  22.882026
# 62369  ...          None  14.7 [10.0-19.9]    14.687933  10.011661  19.877386
#
#       Comments                           Date  TimeDimensionValue  \
# 0         None  2024-02-29T16:06:41.017+01:00                2006
# 1         None  2024-02-29T16:06:41.017+01:00                2017
# 2         None  2024-02-29T16:06:41.017+01:00                2020
# 3         None  2024-02-29T16:06:41.017+01:00                1995
# 4         None  2024-02-29T16:06:41.017+01:00                2003
# ...        ...                            ...                 ...
# 62365     None  2024-02-29T16:06:41.017+01:00                1996
# 62366     None  2024-02-29T16:06:41.017+01:00                2006
# 62367     None  2024-02-29T16:06:41.017+01:00                2009
# 62368     None  2024-02-29T16:06:41.017+01:00                2014
# 62369     None  2024-02-29T16:06:41.017+01:00                2018
#
#               TimeDimensionBegin           TimeDimensionEnd
# 0      2006-01-01T00:00:00+01:00  2006-12-31T00:00:00+01:00
# 1      2017-01-01T00:00:00+01:00  2017-12-31T00:00:00+01:00
# 2      2020-01-01T00:00:00+01:00  2020-12-31T00:00:00+01:00
# 3      1995-01-01T00:00:00+01:00  1995-12-31T00:00:00+01:00
# 4      2003-01-01T00:00:00+01:00  2003-12-31T00:00:00+01:00
# ...                          ...                        ...
# 62365  1996-01-01T00:00:00+01:00  1996-12-31T00:00:00+01:00
# 62366  2006-01-01T00:00:00+01:00  2006-12-31T00:00:00+01:00
# 62367  2009-01-01T00:00:00+01:00  2009-12-31T00:00:00+01:00
# 62368  2014-01-01T00:00:00+01:00  2014-12-31T00:00:00+01:00
# 62369  2018-01-01T00:00:00+01:00  2018-12-31T00:00:00+01:00
#
# [62370 rows x 25 columns]

# %%
import pandas as pd
import requests
import pprint



url = "https://ghoapi.azureedge.net/api/NCD_BMI_18C"

data = requests.get(url)
#print(data.json())

data
# Out:
# <Response [200]>

# %%
pprint.pprint(data.json())
data
# Out:
# Streaming output truncated to the last 5000 lines.
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_BTSX',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS18-PLUS',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 2.4004743,
#             'Id': 10139140,
#             'IndicatorCode': 'NCD_BMI_18C',
#             'Low': 1.1112614,
#             'NumericValue': 1.6710769,
#             'ParentLocation': 'Europe',
#             'ParentLocationCode': 'EUR',
#             'SpatialDim': 'ISL',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2009,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2009-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2009-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2009',
#             'Value': '1.7 [1.1-2.4]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_MLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS18-PLUS',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 3.7482075,
#             'Id': 10139250,
#             'IndicatorCode': 'NCD_BMI_18C',
#             'Low': 2.4008933,
#             'NumericValue': 3.0248459,
#             'ParentLocation': 'Eastern Mediterranean',
#             'ParentLocationCode': 'EMR',
#             'SpatialDim': 'KWT',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 1999,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '1999-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '1999-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '1999',
#             'Value': '3.0 [2.4-3.7]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_BTSX',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS18-PLUS',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 1.8126994,
#             'Id': 10139439,
#             'IndicatorCode': 'NCD_BMI_18C',
#             'Low': 0.91089811,
#             'NumericValue': 1.3053867,
#             'ParentLocation': 'Europe',
#             'ParentLocationCode': 'EUR',
#             'SpatialDim': 'ALB',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2020,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2020-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2020-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2020',
#             'Value': '1.3 [0.9-1.8]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_FMLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS18-PLUS',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 3.1465795,
#             'Id': 10140133,
#             'IndicatorCode': 'NCD_BMI_18C',
#             'Low': 1.7163226,
#             'NumericValue': 2.3626985,
#             'ParentLocation': 'Europe',
#             'ParentLocationCode': 'EUR',
#             'SpatialDim': 'BEL',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2010,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2010-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2010-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2010',
#             'Value': '2.4 [1.7-3.1]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_BTSX',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS18-PLUS',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 8.0936879,
#             'Id': 10140150,
#             'IndicatorCode': 'NCD_BMI_18C',
#             'Low': 4.1572746,
#             'NumericValue': 5.9224788,
#             'ParentLocation': 'Europe',
#             'ParentLocationCode': 'EUR',
#             'SpatialDim': 'TKM',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 1996,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '1996-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '1996-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '1996',
#             'Value': '5.9 [4.2-8.1]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_BTSX',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS18-PLUS',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 23.439294,
#             'Id': 10140201,
#             'IndicatorCode': 'NCD_BMI_18C',
#             'Low': 16.910864,
#             'NumericValue': 20.093973,
#             'ParentLocation': 'Africa',
#             'ParentLocationCode': 'AFR',
#             'SpatialDim': 'NER',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 1999,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '1999-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '1999-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '1999',
#             'Value': '20.1 [16.9-23.4]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_BTSX',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS18-PLUS',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 12.254351,
#             'Id': 10140208,
#             'IndicatorCode': 'NCD_BMI_18C',
#             'Low': 4.7050044,
#             'NumericValue': 8.051794,
#             'ParentLocation': 'Americas',
#             'ParentLocationCode': 'AMR',
#             'SpatialDim': 'VCT',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 1991,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '1991-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '1991-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '1991',
#             'Value': '8.1 [4.7-12.3]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_FMLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS18-PLUS',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 11.81306,
#             'Id': 10140867,
#             'IndicatorCode': 'NCD_BMI_18C',
#             'Low': 0.82213506,
#             'NumericValue': 4.4534862,
#             'ParentLocation': 'Americas',
#             'ParentLocationCode': 'AMR',
#             'SpatialDim': 'ATG',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2018,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2018-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2018-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2018',
#             'Value': '4.5 [0.8-11.8]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_FMLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS18-PLUS',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 18.643197,
#             'Id': 10141413,
#             'IndicatorCode': 'NCD_BMI_18C',
#             'Low': 13.414945,
#             'NumericValue': 15.977968,
#             'ParentLocation': 'Africa',
#             'ParentLocationCode': 'AFR',
#             'SpatialDim': 'SEN',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2001,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2001-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2001-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2001',
#             'Value': '16.0 [13.4-18.6]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_BTSX',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS18-PLUS',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 2.845685,
#             'Id': 10141602,
#             'IndicatorCode': 'NCD_BMI_18C',
#             'Low': 1.6639788,
#             'NumericValue': 2.2019977,
#             'ParentLocation': 'Europe',
#             'ParentLocationCode': 'EUR',
#             'SpatialDim': 'NLD',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 1992,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '1992-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '1992-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '1992',
#             'Value': '2.2 [1.7-2.8]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_BTSX',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS18-PLUS',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 10.635764,
#             'Id': 10141828,
#             'IndicatorCode': 'NCD_BMI_18C',
#             'Low': 5.3692833,
#             'NumericValue': 7.7228613,
#             'ParentLocation': 'Africa',
#             'ParentLocationCode': 'AFR',
#             'SpatialDim': 'GAB',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2014,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2014-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2014-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2014',
#             'Value': '7.7 [5.4-10.6]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_BTSX',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS18-PLUS',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 6.9155432,
#             'Id': 10142283,
#             'IndicatorCode': 'NCD_BMI_18C',
#             'Low': 3.9726458,
#             'NumericValue': 5.3530354,
#             'ParentLocation': 'Eastern Mediterranean',
#             'ParentLocationCode': 'EMR',
#             'SpatialDim': 'BHR',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 1995,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '1995-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '1995-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '1995',
#             'Value': '5.4 [4.0-6.9]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_FMLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS18-PLUS',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 23.159195,
#             'Id': 10142712,
#             'IndicatorCode': 'NCD_BMI_18C',
#             'Low': 17.590538,
#             'NumericValue': 20.314719,
#             'ParentLocation': 'Western Pacific',
#             'ParentLocationCode': 'WPR',
#             'SpatialDim': 'KHM',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2001,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2001-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2001-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2001',
#             'Value': '20.3 [17.6-23.2]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_FMLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS18-PLUS',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 11.233909,
#             'Id': 10142720,
#             'IndicatorCode': 'NCD_BMI_18C',
#             'Low': 7.8809313,
#             'NumericValue': 9.4874494,
#             'ParentLocation': 'Africa',
#             'ParentLocationCode': 'AFR',
#             'SpatialDim': 'TZA',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2014,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2014-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2014-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2014',
#             'Value': '9.5 [7.9-11.2]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_BTSX',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS18-PLUS',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 4.9005069,
#             'Id': 10144455,
#             'IndicatorCode': 'NCD_BMI_18C',
#             'Low': 2.3936296,
#             'NumericValue': 3.5176717,
#             'ParentLocation': 'Europe',
#             'ParentLocationCode': 'EUR',
#             'SpatialDim': 'AZE',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 1993,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '1993-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '1993-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '1993',
#             'Value': '3.5 [2.4-4.9]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_MLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS18-PLUS',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 6.2796757,
#             'Id': 10145451,
#             'IndicatorCode': 'NCD_BMI_18C',
#             'Low': 2.6009932,
#             'NumericValue': 4.2441435,
#             'ParentLocation': 'Eastern Mediterranean',
#             'ParentLocationCode': 'EMR',
#             'SpatialDim': 'IRQ',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2015,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2015-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2015-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2015',
#             'Value': '4.2 [2.6-6.3]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_FMLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS18-PLUS',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 2.4574352,
#             'Id': 10146238,
#             'IndicatorCode': 'NCD_BMI_18C',
#             'Low': 1.5568103,
#             'NumericValue': 1.9820126,
#             'ParentLocation': 'Europe',
#             'ParentLocationCode': 'EUR',
#             'SpatialDim': 'DEU',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2005,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2005-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2005-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2005',
#             'Value': '2.0 [1.6-2.5]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-05-23T13:37:38.457+02:00',
#             'Dim1': 'SEX_BTSX',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS18-PLUS',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 2.477756,
#             'Id': 10146891,
#             'IndicatorCode': 'NCD_BMI_18C',
#             'Low': 2.217946,
#             'NumericValue': 2.34626,
#             'ParentLocation': None,
#             'ParentLocationCode': None,
#             'SpatialDim': 'AMR',
#             'SpatialDimType': 'REGION',
#             'TimeDim': 2013,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2013-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2013-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2013',
#             'Value': '2.3 [2.2-2.5]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_BTSX',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS18-PLUS',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 3.385276,
#             'Id': 10148119,
#             'IndicatorCode': 'NCD_BMI_18C',
#             'Low': 2.0782858,
#             'NumericValue': 2.7008023,
#             'ParentLocation': 'Americas',
#             'ParentLocationCode': 'AMR',
#             'SpatialDim': 'PAN',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2010,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2010-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2010-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2010',
#             'Value': '2.7 [2.1-3.4]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_MLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS18-PLUS',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 23.037596,
#             'Id': 10148563,
#             'IndicatorCode': 'NCD_BMI_18C',
#             'Low': 8.4702186,
#             'NumericValue': 15.042014,
#             'ParentLocation': 'Americas',
#             'ParentLocationCode': 'AMR',
#             'SpatialDim': 'HTI',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2005,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2005-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2005-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2005',
#             'Value': '15.0 [8.5-23.0]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_BTSX',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS18-PLUS',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 8.5872605,
#             'Id': 10148644,
#             'IndicatorCode': 'NCD_BMI_18C',
#             'Low': 7.5677991,
#             'NumericValue': 8.0786854,
#             'ParentLocation': 'Western Pacific',
#             'ParentLocationCode': 'WPR',
#             'SpatialDim': 'JPN',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 1997,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '1997-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '1997-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '1997',
#             'Value': '8.1 [7.6-8.6]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_BTSX',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS18-PLUS',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 7.1304768,
#             'Id': 10148870,
#             'IndicatorCode': 'NCD_BMI_18C',
#             'Low': 2.9366465,
#             'NumericValue': 4.7662895,
#             'ParentLocation': 'Americas',
#             'ParentLocationCode': 'AMR',
#             'SpatialDim': 'DMA',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2015,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2015-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2015-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2015',
#             'Value': '4.8 [2.9-7.1]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_MLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS18-PLUS',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 3.5022654,
#             'Id': 10149235,
#             'IndicatorCode': 'NCD_BMI_18C',
#             'Low': 1.3899659,
#             'NumericValue': 2.2959067,
#             'ParentLocation': 'Americas',
#             'ParentLocationCode': 'AMR',
#             'SpatialDim': 'GTM',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 1999,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '1999-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '1999-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '1999',
#             'Value': '2.3 [1.4-3.5]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-05-23T13:37:38.457+02:00',
#             'Dim1': 'SEX_FMLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS18-PLUS',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 12.643664,
#             'Id': 10150450,
#             'IndicatorCode': 'NCD_BMI_18C',
#             'Low': 10.452847,
#             'NumericValue': 11.526284,
#             'ParentLocation': None,
#             'ParentLocationCode': None,
#             'SpatialDim': 'EMR',
#             'SpatialDimType': 'REGION',
#             'TimeDim': 1997,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '1997-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '1997-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '1997',
#             'Value': '11.5 [10.5-12.6]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_FMLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS18-PLUS',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 4.0711522,
#             'Id': 10151381,
#             'IndicatorCode': 'NCD_BMI_18C',
#             'Low': 1.5042637,
#             'NumericValue': 2.5879396,
#             'ParentLocation': 'Americas',
#             'ParentLocationCode': 'AMR',
#             'SpatialDim': 'SLV',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2019,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2019-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2019-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2019',
#             'Value': '2.6 [1.5-4.1]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_MLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS18-PLUS',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 6.5579571,
#             'Id': 10151858,
#             'IndicatorCode': 'NCD_BMI_18C',
#             'Low': 2.3526434,
#             'NumericValue': 4.184052,
#             'ParentLocation': 'Eastern Mediterranean',
#             'ParentLocationCode': 'EMR',
#             'SpatialDim': 'IRQ',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2018,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2018-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2018-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2018',
#             'Value': '4.2 [2.4-6.6]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_BTSX',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS18-PLUS',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 12.520979,
#             'Id': 10152595,
#             'IndicatorCode': 'NCD_BMI_18C',
#             'Low': 6.618081,
#             'NumericValue': 9.3195088,
#             'ParentLocation': 'Africa',
#             'ParentLocationCode': 'AFR',
#             'SpatialDim': 'GAB',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2005,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2005-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2005-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2005',
#             'Value': '9.3 [6.6-12.5]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_BTSX',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS18-PLUS',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 4.9591683,
#             'Id': 10152685,
#             'IndicatorCode': 'NCD_BMI_18C',
#             'Low': 2.1679072,
#             'NumericValue': 3.2769367,
#             'ParentLocation': 'Americas',
#             'ParentLocationCode': 'AMR',
#             'SpatialDim': 'HND',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2009,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2009-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2009-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2009',
#             'Value': '3.3 [2.2-5.0]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_BTSX',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS18-PLUS',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 5.7083156,
#             'Id': 10153228,
#             'IndicatorCode': 'NCD_BMI_18C',
#             'Low': 3.6505591,
#             'NumericValue': 4.6301849,
#             'ParentLocation': 'Eastern Mediterranean',
#             'ParentLocationCode': 'EMR',
#             'SpatialDim': 'TUN',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2009,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2009-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2009-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2009',
#             'Value': '4.6 [3.7-5.7]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_BTSX',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS18-PLUS',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 18.56928,
#             'Id': 10153511,
#             'IndicatorCode': 'NCD_BMI_18C',
#             'Low': 12.796298,
#             'NumericValue': 15.617818,
#             'ParentLocation': 'Africa',
#             'ParentLocationCode': 'AFR',
#             'SpatialDim': 'NAM',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2011,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2011-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2011-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2011',
#             'Value': '15.6 [12.8-18.6]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_MLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS18-PLUS',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 12.524925,
#             'Id': 10153654,
#             'IndicatorCode': 'NCD_BMI_18C',
#             'Low': 7.5155996,
#             'NumericValue': 9.8488562,
#             'ParentLocation': 'Africa',
#             'ParentLocationCode': 'AFR',
#             'SpatialDim': 'BFA',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2016,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2016-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2016-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2016',
#             'Value': '9.8 [7.5-12.5]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_FMLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS18-PLUS',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 13.766956,
#             'Id': 10153674,
#             'IndicatorCode': 'NCD_BMI_18C',
#             'Low': 5.633254,
#             'NumericValue': 9.2669703,
#             'ParentLocation': 'Europe',
#             'ParentLocationCode': 'EUR',
#             'SpatialDim': 'TKM',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 1992,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '1992-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '1992-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '1992',
#             'Value': '9.3 [5.6-13.8]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_FMLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS18-PLUS',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 4.6734817,
#             'Id': 10153764,
#             'IndicatorCode': 'NCD_BMI_18C',
#             'Low': 1.9399861,
#             'NumericValue': 3.1761356,
#             'ParentLocation': 'Europe',
#             'ParentLocationCode': 'EUR',
#             'SpatialDim': 'BLR',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2011,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2011-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2011-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2011',
#             'Value': '3.2 [1.9-4.7]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_MLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS18-PLUS',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 21.379152,
#             'Id': 10153769,
#             'IndicatorCode': 'NCD_BMI_18C',
#             'Low': 10.661267,
#             'NumericValue': 15.775563,
#             'ParentLocation': 'Africa',
#             'ParentLocationCode': 'AFR',
#             'SpatialDim': 'COD',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2018,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2018-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2018-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2018',
#             'Value': '15.8 [10.7-21.4]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_FMLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS18-PLUS',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 4.8670895,
#             'Id': 10154048,
#             'IndicatorCode': 'NCD_BMI_18C',
#             'Low': 1.8921301,
#             'NumericValue': 3.1909935,
#             'ParentLocation': 'Europe',
#             'ParentLocationCode': 'EUR',
#             'SpatialDim': 'GRC',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 1994,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '1994-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '1994-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '1994',
#             'Value': '3.2 [1.9-4.9]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-05-23T13:37:38.457+02:00',
#             'Dim1': 'SEX_MLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS18-PLUS',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 9.267447,
#             'Id': 10154926,
#             'IndicatorCode': 'NCD_BMI_18C',
#             'Low': 8.585576,
#             'NumericValue': 8.92772,
#             'ParentLocation': None,
#             'ParentLocationCode': None,
#             'SpatialDim': 'GLOBAL',
#             'SpatialDimType': 'GLOBAL',
#             'TimeDim': 2013,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2013-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2013-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2013',
#             'Value': '8.9 [8.6-9.3]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_BTSX',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS18-PLUS',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 10.419314,
#             'Id': 10156256,
#             'IndicatorCode': 'NCD_BMI_18C',
#             'Low': 6.4282678,
#             'NumericValue': 8.3357088,
#             'ParentLocation': 'Africa',
#             'ParentLocationCode': 'AFR',
#             'SpatialDim': 'STP',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2003,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2003-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2003-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2003',
#             'Value': '8.3 [6.4-10.4]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_MLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS18-PLUS',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 1.3765253,
#             'Id': 10156474,
#             'IndicatorCode': 'NCD_BMI_18C',
#             'Low': 0.40039942,
#             'NumericValue': 0.78778006,
#             'ParentLocation': 'Europe',
#             'ParentLocationCode': 'EUR',
#             'SpatialDim': 'ESP',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2019,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2019-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2019-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2019',
#             'Value': '0.8 [0.4-1.4]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_MLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS18-PLUS',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 2.9066712,
#             'Id': 10156492,
#             'IndicatorCode': 'NCD_BMI_18C',
#             'Low': 1.4096956,
#             'NumericValue': 2.0767005,
#             'ParentLocation': 'Americas',
#             'ParentLocationCode': 'AMR',
#             'SpatialDim': 'ECU',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2010,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2010-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2010-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2010',
#             'Value': '2.1 [1.4-2.9]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_MLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS18-PLUS',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 7.0161626,
#             'Id': 10157823,
#             'IndicatorCode': 'NCD_BMI_18C',
#             'Low': 1.1837344,
#             'NumericValue': 3.3827078,
#             'ParentLocation': 'Americas',
#             'ParentLocationCode': 'AMR',
#             'SpatialDim': 'NIC',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2010,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2010-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2010-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2010',
#             'Value': '3.4 [1.2-7.0]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_MLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS18-PLUS',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 4.3225106,
#             'Id': 10157984,
#             'IndicatorCode': 'NCD_BMI_18C',
#             'Low': 1.4880332,
#             'NumericValue': 2.6789688,
#             'ParentLocation': 'Americas',
#             'ParentLocationCode': 'AMR',
#             'SpatialDim': 'GTM',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 1995,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '1995-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '1995-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '1995',
#             'Value': '2.7 [1.5-4.3]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_BTSX',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS18-PLUS',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 20.542362,
#             'Id': 10158150,
#             'IndicatorCode': 'NCD_BMI_18C',
#             'Low': 13.5646,
#             'NumericValue': 16.915572,
#             'ParentLocation': 'Eastern Mediterranean',
#             'ParentLocationCode': 'EMR',
#             'SpatialDim': 'SDN',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2005,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2005-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2005-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2005',
#             'Value': '16.9 [13.6-20.5]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_BTSX',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS18-PLUS',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 3.9961357,
#             'Id': 10158575,
#             'IndicatorCode': 'NCD_BMI_18C',
#             'Low': 1.6055077,
#             'NumericValue': 2.6673056,
#             'ParentLocation': 'Europe',
#             'ParentLocationCode': 'EUR',
#             'SpatialDim': 'BIH',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 1999,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '1999-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '1999-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '1999',
#             'Value': '2.7 [1.6-4.0]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_MLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS18-PLUS',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 0.47878535,
#             'Id': 10160300,
#             'IndicatorCode': 'NCD_BMI_18C',
#             'Low': 0.095831184,
#             'NumericValue': 0.2412549,
#             'ParentLocation': 'Western Pacific',
#             'ParentLocationCode': 'WPR',
#             'SpatialDim': 'WSM',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2001,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2001-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2001-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2001',
#             'Value': '0.2 [0.1-0.5]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_BTSX',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS18-PLUS',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 3.7979722,
#             'Id': 10160760,
#             'IndicatorCode': 'NCD_BMI_18C',
#             'Low': 2.9071484,
#             'NumericValue': 3.3353042,
#             'ParentLocation': 'Americas',
#             'ParentLocationCode': 'AMR',
#             'SpatialDim': 'COL',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2008,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2008-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2008-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2008',
#             'Value': '3.3 [2.9-3.8]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_BTSX',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS18-PLUS',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 6.1078262,
#             'Id': 10161215,
#             'IndicatorCode': 'NCD_BMI_18C',
#             'Low': 2.5833953,
#             'NumericValue': 4.0811799,
#             'ParentLocation': 'Africa',
#             'ParentLocationCode': 'AFR',
#             'SpatialDim': 'SYC',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2018,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2018-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2018-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2018',
#             'Value': '4.1 [2.6-6.1]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_FMLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS18-PLUS',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 5.9326656,
#             'Id': 10161388,
#             'IndicatorCode': 'NCD_BMI_18C',
#             'Low': 3.1680703,
#             'NumericValue': 4.4136733,
#             'ParentLocation': 'Eastern Mediterranean',
#             'ParentLocationCode': 'EMR',
#             'SpatialDim': 'MAR',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2015,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2015-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2015-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2015',
#             'Value': '4.4 [3.2-5.9]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_MLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS18-PLUS',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 26.695171,
#             'Id': 10161570,
#             'IndicatorCode': 'NCD_BMI_18C',
#             'Low': 5.2657809,
#             'NumericValue': 13.955906,
#             'ParentLocation': 'Eastern Mediterranean',
#             'ParentLocationCode': 'EMR',
#             'SpatialDim': 'DJI',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2020,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2020-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2020-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2020',
#             'Value': '14.0 [5.3-26.7]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_BTSX',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS18-PLUS',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 11.720743,
#             'Id': 10161985,
#             'IndicatorCode': 'NCD_BMI_18C',
#             'Low': 5.0082784,
#             'NumericValue': 8.0602676,
#             'ParentLocation': 'Americas',
#             'ParentLocationCode': 'AMR',
#             'SpatialDim': 'DMA',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 1993,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '1993-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '1993-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '1993',
#             'Value': '8.1 [5.0-11.7]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_BTSX',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS18-PLUS',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 19.655378,
#             'Id': 10163126,
#             'IndicatorCode': 'NCD_BMI_18C',
#             'Low': 13.546656,
#             'NumericValue': 16.484734,
#             'ParentLocation': 'Eastern Mediterranean',
#             'ParentLocationCode': 'EMR',
#             'SpatialDim': 'SDN',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2009,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2009-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2009-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2009',
#             'Value': '16.5 [13.5-19.7]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
# ...
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 2.7903233,
#             'Id': 10225248,
#             'IndicatorCode': 'NCD_BMI_18C',
#             'Low': 2.0469634,
#             'NumericValue': 2.402506,
#             'ParentLocation': 'Americas',
#             'ParentLocationCode': 'AMR',
#             'SpatialDim': 'MEX',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2002,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2002-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2002-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2002',
#             'Value': '2.4 [2.0-2.8]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_FMLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS18-PLUS',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 10.84744,
#             'Id': 10225722,
#             'IndicatorCode': 'NCD_BMI_18C',
#             'Low': 9.0745471,
#             'NumericValue': 9.9336661,
#             'ParentLocation': 'Western Pacific',
#             'ParentLocationCode': 'WPR',
#             'SpatialDim': 'CHN',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 1996,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '1996-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '1996-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '1996',
#             'Value': '9.9 [9.1-10.8]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_FMLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS18-PLUS',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 15.507659,
#             'Id': 10226680,
#             'IndicatorCode': 'NCD_BMI_18C',
#             'Low': 13.30808,
#             'NumericValue': 14.335483,
#             'ParentLocation': None,
#             'ParentLocationCode': None,
#             'SpatialDim': 'WB_LI',
#             'SpatialDimType': 'WORLDBANKINCOMEGROUP',
#             'TimeDim': 2017,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2017-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2017-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2017',
#             'Value': '14.3 [13.3-15.5]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_MLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS18-PLUS',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 18.59619,
#             'Id': 10227676,
#             'IndicatorCode': 'NCD_BMI_18C',
#             'Low': 10.360934,
#             'NumericValue': 14.186259,
#             'ParentLocation': 'Africa',
#             'ParentLocationCode': 'AFR',
#             'SpatialDim': 'UGA',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2000,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2000-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2000-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2000',
#             'Value': '14.2 [10.4-18.6]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_MLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS18-PLUS',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 12.466729,
#             'Id': 10227844,
#             'IndicatorCode': 'NCD_BMI_18C',
#             'Low': 7.5367779,
#             'NumericValue': 9.8537147,
#             'ParentLocation': 'Africa',
#             'ParentLocationCode': 'AFR',
#             'SpatialDim': 'SLE',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2012,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2012-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2012-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2012',
#             'Value': '9.9 [7.5-12.5]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_MLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS18-PLUS',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 0.47272318,
#             'Id': 10229151,
#             'IndicatorCode': 'NCD_BMI_18C',
#             'Low': 0.093352428,
#             'NumericValue': 0.2371558,
#             'ParentLocation': 'Western Pacific',
#             'ParentLocationCode': 'WPR',
#             'SpatialDim': 'WSM',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2004,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2004-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2004-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2004',
#             'Value': '0.2 [0.1-0.5]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_BTSX',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS18-PLUS',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 6.3865297,
#             'Id': 10229439,
#             'IndicatorCode': 'NCD_BMI_18C',
#             'Low': 5.0925594,
#             'NumericValue': 5.7229217,
#             'ParentLocation': 'Africa',
#             'ParentLocationCode': 'AFR',
#             'SpatialDim': 'ZAF',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2013,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2013-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2013-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2013',
#             'Value': '5.7 [5.1-6.4]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_FMLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS18-PLUS',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 43.393871,
#             'Id': 10229891,
#             'IndicatorCode': 'NCD_BMI_18C',
#             'Low': 38.684949,
#             'NumericValue': 41.054887,
#             'ParentLocation': 'South-East Asia',
#             'ParentLocationCode': 'SEAR',
#             'SpatialDim': 'IND',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 1991,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '1991-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '1991-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '1991',
#             'Value': '41.1 [38.7-43.4]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_MLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS18-PLUS',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 1.8095495,
#             'Id': 10230372,
#             'IndicatorCode': 'NCD_BMI_18C',
#             'Low': 0.51876777,
#             'NumericValue': 1.0428953,
#             'ParentLocation': 'Europe',
#             'ParentLocationCode': 'EUR',
#             'SpatialDim': 'BGR',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2021,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2021-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2021-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2021',
#             'Value': '1.0 [0.5-1.8]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_MLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS18-PLUS',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 16.927955,
#             'Id': 10230419,
#             'IndicatorCode': 'NCD_BMI_18C',
#             'Low': 9.4153769,
#             'NumericValue': 12.900943,
#             'ParentLocation': 'Africa',
#             'ParentLocationCode': 'AFR',
#             'SpatialDim': 'ZMB',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2011,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2011-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2011-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2011',
#             'Value': '12.9 [9.4-16.9]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_BTSX',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS18-PLUS',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 27.238068,
#             'Id': 10230703,
#             'IndicatorCode': 'NCD_BMI_18C',
#             'Low': 13.561094,
#             'NumericValue': 20.191449,
#             'ParentLocation': 'Eastern Mediterranean',
#             'ParentLocationCode': 'EMR',
#             'SpatialDim': 'SOM',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2002,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2002-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2002-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2002',
#             'Value': '20.2 [13.6-27.2]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_MLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS18-PLUS',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 2.2886284,
#             'Id': 10230727,
#             'IndicatorCode': 'NCD_BMI_18C',
#             'Low': 1.4674358,
#             'NumericValue': 1.8476946,
#             'ParentLocation': 'Americas',
#             'ParentLocationCode': 'AMR',
#             'SpatialDim': 'MEX',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2002,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2002-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2002-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2002',
#             'Value': '1.8 [1.5-2.3]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_MLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS18-PLUS',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 3.5776045,
#             'Id': 10231599,
#             'IndicatorCode': 'NCD_BMI_18C',
#             'Low': 1.2046446,
#             'NumericValue': 2.2135327,
#             'ParentLocation': 'Europe',
#             'ParentLocationCode': 'EUR',
#             'SpatialDim': 'BGR',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 1997,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '1997-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '1997-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '1997',
#             'Value': '2.2 [1.2-3.6]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_MLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS18-PLUS',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 1.5965078,
#             'Id': 10231994,
#             'IndicatorCode': 'NCD_BMI_18C',
#             'Low': 0.9323488,
#             'NumericValue': 1.2324104,
#             'ParentLocation': 'Europe',
#             'ParentLocationCode': 'EUR',
#             'SpatialDim': 'ITA',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 1991,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '1991-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '1991-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '1991',
#             'Value': '1.2 [0.9-1.6]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_BTSX',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS18-PLUS',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 20.722955,
#             'Id': 10232283,
#             'IndicatorCode': 'NCD_BMI_18C',
#             'Low': 6.2024605,
#             'NumericValue': 12.46924,
#             'ParentLocation': 'South-East Asia',
#             'ParentLocationCode': 'SEAR',
#             'SpatialDim': 'PRK',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2013,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2013-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2013-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2013',
#             'Value': '12.5 [6.2-20.7]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_MLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS18-PLUS',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 15.543477,
#             'Id': 10232343,
#             'IndicatorCode': 'NCD_BMI_18C',
#             'Low': 2.3609024,
#             'NumericValue': 7.3025234,
#             'ParentLocation': 'Americas',
#             'ParentLocationCode': 'AMR',
#             'SpatialDim': 'BMU',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 1998,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '1998-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '1998-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '1998',
#             'Value': '7.3 [2.4-15.5]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_MLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS18-PLUS',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 1.1887958,
#             'Id': 10232479,
#             'IndicatorCode': 'NCD_BMI_18C',
#             'Low': 0.80044344,
#             'NumericValue': 0.9822553,
#             'ParentLocation': 'Americas',
#             'ParentLocationCode': 'AMR',
#             'SpatialDim': 'USA',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2007,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2007-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2007-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2007',
#             'Value': '1.0 [0.8-1.2]'}]}
# <Response [200]>

# %%
import pandas as pd
malnutrition=[]
malnutrition=data.json()["value"]
df_malnutrition=pd.DataFrame(malnutrition)
df_malnutrition
# Out:
#             Id IndicatorCode        SpatialDimType SpatialDim  \
# 0      9413921   NCD_BMI_18C               COUNTRY        BRA
# 1      9415159   NCD_BMI_18C               COUNTRY        KAZ
# 2      9415431   NCD_BMI_18C               COUNTRY        BRN
# 3      9415473   NCD_BMI_18C               COUNTRY        ZWE
# 4      9415841   NCD_BMI_18C  WORLDBANKINCOMEGROUP     WB_UMI
# ...        ...           ...                   ...        ...
# 20785  9411488   NCD_BMI_18C               COUNTRY        BRA
# 20786  9412271   NCD_BMI_18C               COUNTRY        BWA
# 20787  9412347   NCD_BMI_18C                REGION        WPR
# 20788  9412894   NCD_BMI_18C               COUNTRY        GHA
# 20789  9413195   NCD_BMI_18C               COUNTRY        BFA
#
#       ParentLocationCode TimeDimType   ParentLocation Dim1Type  TimeDim  \
# 0                    AMR        YEAR         Americas      SEX     2001
# 1                    EUR        YEAR           Europe      SEX     1991
# 2                    WPR        YEAR  Western Pacific      SEX     1992
# 3                    AFR        YEAR           Africa      SEX     1995
# 4                   None        YEAR             None      SEX     1993
# ...                  ...         ...              ...      ...      ...
# 20785                AMR        YEAR         Americas      SEX     2000
# 20786                AFR        YEAR           Africa      SEX     2015
# 20787               None        YEAR             None      SEX     2003
# 20788                AFR        YEAR           Africa      SEX     2014
# 20789                AFR        YEAR           Africa      SEX     2018
#
#            Dim1  ... DataSourceDim             Value NumericValue        Low  \
# 0      SEX_FMLE  ...          None     5.4 [4.7-6.2]     5.415983   4.658800
# 1       SEX_MLE  ...          None     4.1 [2.1-6.9]     4.083322   2.087229
# 2       SEX_MLE  ...          None   11.9 [6.2-19.4]    11.859050   6.237043
# 3       SEX_MLE  ...          None  16.8 [12.6-21.4]    16.840979  12.633739
# 4      SEX_FMLE  ...          None     9.3 [8.7-9.9]     9.309030   8.719388
# ...         ...  ...           ...               ...          ...        ...
# 20785  SEX_BTSX  ...          None     4.7 [4.1-5.3]     4.663565   4.126446
# 20786   SEX_MLE  ...          None  18.5 [13.7-23.3]    18.480983  13.728492
# 20787  SEX_BTSX  ...          None     8.8 [8.4-9.2]     8.773462   8.372438
# 20788   SEX_MLE  ...          None    8.2 [6.6-10.0]     8.181823   6.574282
# 20789  SEX_FMLE  ...          None  13.4 [11.5-15.5]    13.426639  11.513353
#
#             High Comments                           Date  TimeDimensionValue  \
# 0       6.199365     None  2024-02-29T16:06:41.017+01:00                2001
# 1       6.851229     None  2024-02-29T16:06:41.017+01:00                1991
# 2      19.428556     None  2024-02-29T16:06:41.017+01:00                1992
# 3      21.442428     None  2024-02-29T16:06:41.017+01:00                1995
# 4       9.941361     None  2024-02-29T16:06:41.017+01:00                1993
# ...          ...      ...                            ...                 ...
# 20785   5.252849     None  2024-02-29T16:06:41.017+01:00                2000
# 20786  23.267952     None  2024-02-29T16:06:41.017+01:00                2015
# 20787   9.183418     None  2024-05-23T13:37:38.457+02:00                2003
# 20788   9.973383     None  2024-02-29T16:06:41.017+01:00                2014
# 20789  15.458266     None  2024-02-29T16:06:41.017+01:00                2018
#
#               TimeDimensionBegin           TimeDimensionEnd
# 0      2001-01-01T00:00:00+01:00  2001-12-31T00:00:00+01:00
# 1      1991-01-01T00:00:00+01:00  1991-12-31T00:00:00+01:00
# 2      1992-01-01T00:00:00+01:00  1992-12-31T00:00:00+01:00
# 3      1995-01-01T00:00:00+01:00  1995-12-31T00:00:00+01:00
# 4      1993-01-01T00:00:00+01:00  1993-12-31T00:00:00+01:00
# ...                          ...                        ...
# 20785  2000-01-01T00:00:00+01:00  2000-12-31T00:00:00+01:00
# 20786  2015-01-01T00:00:00+01:00  2015-12-31T00:00:00+01:00
# 20787  2003-01-01T00:00:00+01:00  2003-12-31T00:00:00+01:00
# 20788  2014-01-01T00:00:00+01:00  2014-12-31T00:00:00+01:00
# 20789  2018-01-01T00:00:00+01:00  2018-12-31T00:00:00+01:00
#
# [20790 rows x 25 columns]

# %%
import pandas as pd
import requests
import pprint



url = "https://ghoapi.azureedge.net/api/NCD_BMI_MINUS2C"

data = requests.get(url)
#print(data.json())

data
# Out:
# <Response [200]>

# %%
pprint.pprint(data.json())
data
# Out:
# Streaming output truncated to the last 5000 lines.
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_FMLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS10-19',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 12.293187,
#             'Id': 10196559,
#             'IndicatorCode': 'NCD_BMI_MINUS2C',
#             'Low': 1.8450763,
#             'NumericValue': 5.8373939,
#             'ParentLocation': 'Eastern Mediterranean',
#             'ParentLocationCode': 'EMR',
#             'SpatialDim': 'SOM',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2013,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2013-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2013-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2013',
#             'Value': '5.8 [1.8-12.3]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_FMLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS10-19',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 3.3621449,
#             'Id': 10196651,
#             'IndicatorCode': 'NCD_BMI_MINUS2C',
#             'Low': 1.3717135,
#             'NumericValue': 2.2327926,
#             'ParentLocation': 'Europe',
#             'ParentLocationCode': 'EUR',
#             'SpatialDim': 'FRA',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2019,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2019-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2019-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2019',
#             'Value': '2.2 [1.4-3.4]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_FMLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS10-19',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 1.5402004,
#             'Id': 10196907,
#             'IndicatorCode': 'NCD_BMI_MINUS2C',
#             'Low': 0.93951263,
#             'NumericValue': 1.2211381,
#             'ParentLocation': 'Europe',
#             'ParentLocationCode': 'EUR',
#             'SpatialDim': 'GBR',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2019,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2019-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2019-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2019',
#             'Value': '1.2 [0.9-1.5]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_MLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS05-09',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 8.4265232,
#             'Id': 10196931,
#             'IndicatorCode': 'NCD_BMI_MINUS2C',
#             'Low': 0.50881319,
#             'NumericValue': 2.9586948,
#             'ParentLocation': 'Western Pacific',
#             'ParentLocationCode': 'WPR',
#             'SpatialDim': 'TUV',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2001,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2001-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2001-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2001',
#             'Value': '3.0 [0.5-8.4]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_FMLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS10-19',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 2.0048812,
#             'Id': 10197032,
#             'IndicatorCode': 'NCD_BMI_MINUS2C',
#             'Low': 0.15048591,
#             'NumericValue': 0.74097901,
#             'ParentLocation': 'Western Pacific',
#             'ParentLocationCode': 'WPR',
#             'SpatialDim': 'TUV',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2000,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2000-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2000-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2000',
#             'Value': '0.7 [0.2-2.0]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_MLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS05-09',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 8.6276174,
#             'Id': 10197058,
#             'IndicatorCode': 'NCD_BMI_MINUS2C',
#             'Low': 0.4736532,
#             'NumericValue': 2.9917985,
#             'ParentLocation': 'Americas',
#             'ParentLocationCode': 'AMR',
#             'SpatialDim': 'ATG',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2019,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2019-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2019-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2019',
#             'Value': '3.0 [0.5-8.6]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_MLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS05-09',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 1.8896379,
#             'Id': 10197320,
#             'IndicatorCode': 'NCD_BMI_MINUS2C',
#             'Low': 1.0266283,
#             'NumericValue': 1.413342,
#             'ParentLocation': 'Americas',
#             'ParentLocationCode': 'AMR',
#             'SpatialDim': 'PER',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2015,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2015-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2015-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2015',
#             'Value': '1.4 [1.0-1.9]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_BTSX',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS10-19',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 3.3660758,
#             'Id': 10197487,
#             'IndicatorCode': 'NCD_BMI_MINUS2C',
#             'Low': 0.84886895,
#             'NumericValue': 1.843857,
#             'ParentLocation': 'Western Pacific',
#             'ParentLocationCode': 'WPR',
#             'SpatialDim': 'MHL',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2008,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2008-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2008-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2008',
#             'Value': '1.8 [0.8-3.4]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_MLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS10-19',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 3.9723549,
#             'Id': 10197698,
#             'IndicatorCode': 'NCD_BMI_MINUS2C',
#             'Low': 1.5179268,
#             'NumericValue': 2.5994554,
#             'ParentLocation': 'Europe',
#             'ParentLocationCode': 'EUR',
#             'SpatialDim': 'SWE',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2021,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2021-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2021-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2021',
#             'Value': '2.6 [1.5-4.0]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_BTSX',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS10-19',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 21.202414,
#             'Id': 10197711,
#             'IndicatorCode': 'NCD_BMI_MINUS2C',
#             'Low': 14.733139,
#             'NumericValue': 17.906308,
#             'ParentLocation': 'Africa',
#             'ParentLocationCode': 'AFR',
#             'SpatialDim': 'SEN',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2012,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2012-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2012-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2012',
#             'Value': '17.9 [14.7-21.2]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_MLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS05-19',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 4.3257482,
#             'Id': 10197719,
#             'IndicatorCode': 'NCD_BMI_MINUS2C',
#             'Low': 2.2972101,
#             'NumericValue': 3.2148901,
#             'ParentLocation': 'Europe',
#             'ParentLocationCode': 'EUR',
#             'SpatialDim': 'BGR',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2014,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2014-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2014-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2014',
#             'Value': '3.2 [2.3-4.3]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_BTSX',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS10-19',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 5.7399038,
#             'Id': 10198114,
#             'IndicatorCode': 'NCD_BMI_MINUS2C',
#             'Low': 4.6181154,
#             'NumericValue': 5.1573504,
#             'ParentLocation': 'Africa',
#             'ParentLocationCode': 'AFR',
#             'SpatialDim': 'ZAF',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2011,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2011-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2011-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2011',
#             'Value': '5.2 [4.6-5.7]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_FMLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS05-19',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 2.5039768,
#             'Id': 10198576,
#             'IndicatorCode': 'NCD_BMI_MINUS2C',
#             'Low': 1.4293436,
#             'NumericValue': 1.9189306,
#             'ParentLocation': 'Europe',
#             'ParentLocationCode': 'EUR',
#             'SpatialDim': 'EST',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2016,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2016-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2016-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2016',
#             'Value': '1.9 [1.4-2.5]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-05-23T13:28:38.2+02:00',
#             'Dim1': 'SEX_FMLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS05-09',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 12.365912,
#             'Id': 10198607,
#             'IndicatorCode': 'NCD_BMI_MINUS2C',
#             'Low': 9.024332,
#             'NumericValue': 10.624558,
#             'ParentLocation': None,
#             'ParentLocationCode': None,
#             'SpatialDim': 'EMR',
#             'SpatialDimType': 'REGION',
#             'TimeDim': 1998,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '1998-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '1998-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '1998',
#             'Value': '10.6 [9.0-12.4]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_MLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS05-09',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 1.6269669,
#             'Id': 10199179,
#             'IndicatorCode': 'NCD_BMI_MINUS2C',
#             'Low': 0.90568895,
#             'NumericValue': 1.2370097,
#             'ParentLocation': 'Europe',
#             'ParentLocationCode': 'EUR',
#             'SpatialDim': 'CHE',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2003,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2003-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2003-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2003',
#             'Value': '1.2 [0.9-1.6]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_FMLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS05-09',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 8.2095399,
#             'Id': 10199424,
#             'IndicatorCode': 'NCD_BMI_MINUS2C',
#             'Low': 1.0300357,
#             'NumericValue': 3.5755523,
#             'ParentLocation': 'Eastern Mediterranean',
#             'ParentLocationCode': 'EMR',
#             'SpatialDim': 'PSE',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 1993,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '1993-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '1993-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '1993',
#             'Value': '3.6 [1.0-8.2]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_BTSX',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS05-09',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 8.3923168,
#             'Id': 10199664,
#             'IndicatorCode': 'NCD_BMI_MINUS2C',
#             'Low': 2.3544502,
#             'NumericValue': 4.7205076,
#             'ParentLocation': 'Africa',
#             'ParentLocationCode': 'AFR',
#             'SpatialDim': 'RWA',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2013,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2013-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2013-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2013',
#             'Value': '4.7 [2.4-8.4]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_BTSX',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS05-19',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 6.5238498,
#             'Id': 10199841,
#             'IndicatorCode': 'NCD_BMI_MINUS2C',
#             'Low': 5.7814471,
#             'NumericValue': 6.1433259,
#             'ParentLocation': None,
#             'ParentLocationCode': None,
#             'SpatialDim': 'WB_UMI',
#             'SpatialDimType': 'WORLDBANKINCOMEGROUP',
#             'TimeDim': 1999,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '1999-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '1999-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '1999',
#             'Value': '6.1 [5.8-6.5]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_MLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS05-19',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 29.054257,
#             'Id': 10200046,
#             'IndicatorCode': 'NCD_BMI_MINUS2C',
#             'Low': 15.72112,
#             'NumericValue': 22.012956,
#             'ParentLocation': 'Africa',
#             'ParentLocationCode': 'AFR',
#             'SpatialDim': 'SEN',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2010,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2010-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2010-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2010',
#             'Value': '22.0 [15.7-29.1]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_MLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS05-19',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 27.367991,
#             'Id': 10200089,
#             'IndicatorCode': 'NCD_BMI_MINUS2C',
#             'Low': 10.45386,
#             'NumericValue': 18.312722,
#             'ParentLocation': 'Eastern Mediterranean',
#             'ParentLocationCode': 'EMR',
#             'SpatialDim': 'SDN',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2009,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2009-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2009-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2009',
#             'Value': '18.3 [10.5-27.4]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_BTSX',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS05-19',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 8.4404714,
#             'Id': 10200133,
#             'IndicatorCode': 'NCD_BMI_MINUS2C',
#             'Low': 5.1437065,
#             'NumericValue': 6.6691957,
#             'ParentLocation': 'Eastern Mediterranean',
#             'ParentLocationCode': 'EMR',
#             'SpatialDim': 'TUN',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 1994,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '1994-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '1994-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '1994',
#             'Value': '6.7 [5.1-8.4]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_BTSX',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS10-19',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 11.455397,
#             'Id': 10200168,
#             'IndicatorCode': 'NCD_BMI_MINUS2C',
#             'Low': 3.3440161,
#             'NumericValue': 6.8733074,
#             'ParentLocation': 'Western Pacific',
#             'ParentLocationCode': 'WPR',
#             'SpatialDim': 'LAO',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2018,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2018-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2018-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2018',
#             'Value': '6.9 [3.3-11.5]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_BTSX',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS05-09',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 10.192975,
#             'Id': 10200428,
#             'IndicatorCode': 'NCD_BMI_MINUS2C',
#             'Low': 8.5224815,
#             'NumericValue': 9.3317345,
#             'ParentLocation': 'Eastern Mediterranean',
#             'ParentLocationCode': 'EMR',
#             'SpatialDim': 'IRN',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2008,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2008-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2008-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2008',
#             'Value': '9.3 [8.5-10.2]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_MLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS05-09',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 0.97854566,
#             'Id': 10200595,
#             'IndicatorCode': 'NCD_BMI_MINUS2C',
#             'Low': 0.51810257,
#             'NumericValue': 0.72568329,
#             'ParentLocation': 'Europe',
#             'ParentLocationCode': 'EUR',
#             'SpatialDim': 'PRT',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2006,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2006-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2006-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2006',
#             'Value': '0.7 [0.5-1.0]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_FMLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS10-19',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 10.047673,
#             'Id': 10200630,
#             'IndicatorCode': 'NCD_BMI_MINUS2C',
#             'Low': 7.4366577,
#             'NumericValue': 8.7063424,
#             'ParentLocation': 'Western Pacific',
#             'ParentLocationCode': 'WPR',
#             'SpatialDim': 'PHL',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2007,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2007-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2007-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2007',
#             'Value': '8.7 [7.4-10.0]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_FMLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS10-19',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 7.3152997,
#             'Id': 10200937,
#             'IndicatorCode': 'NCD_BMI_MINUS2C',
#             'Low': 1.2341847,
#             'NumericValue': 3.4865633,
#             'ParentLocation': 'Eastern Mediterranean',
#             'ParentLocationCode': 'EMR',
#             'SpatialDim': 'IRQ',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 1993,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '1993-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '1993-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '1993',
#             'Value': '3.5 [1.2-7.3]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_MLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS10-19',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 2.0750245,
#             'Id': 10201031,
#             'IndicatorCode': 'NCD_BMI_MINUS2C',
#             'Low': 0.13583974,
#             'NumericValue': 0.72677191,
#             'ParentLocation': 'Western Pacific',
#             'ParentLocationCode': 'WPR',
#             'SpatialDim': 'FSM',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2006,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2006-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2006-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2006',
#             'Value': '0.7 [0.1-2.1]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_BTSX',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS10-19',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 18.147112,
#             'Id': 10201202,
#             'IndicatorCode': 'NCD_BMI_MINUS2C',
#             'Low': 5.0178818,
#             'NumericValue': 10.765683,
#             'ParentLocation': 'Africa',
#             'ParentLocationCode': 'AFR',
#             'SpatialDim': 'GNQ',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2006,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2006-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2006-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2006',
#             'Value': '10.8 [5.0-18.1]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_BTSX',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS05-19',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 23.319428,
#             'Id': 10201304,
#             'IndicatorCode': 'NCD_BMI_MINUS2C',
#             'Low': 12.519568,
#             'NumericValue': 17.53417,
#             'ParentLocation': 'South-East Asia',
#             'ParentLocationCode': 'SEAR',
#             'SpatialDim': 'MDV',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 1996,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '1996-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '1996-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '1996',
#             'Value': '17.5 [12.5-23.3]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_BTSX',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS05-09',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 1.6600752,
#             'Id': 10201324,
#             'IndicatorCode': 'NCD_BMI_MINUS2C',
#             'Low': 0.78852009,
#             'NumericValue': 1.1712214,
#             'ParentLocation': 'Europe',
#             'ParentLocationCode': 'EUR',
#             'SpatialDim': 'ITA',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 1996,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '1996-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '1996-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '1996',
#             'Value': '1.2 [0.8-1.7]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_MLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS05-19',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 3.4218382,
#             'Id': 10201359,
#             'IndicatorCode': 'NCD_BMI_MINUS2C',
#             'Low': 1.5174285,
#             'NumericValue': 2.3138169,
#             'ParentLocation': 'Europe',
#             'ParentLocationCode': 'EUR',
#             'SpatialDim': 'LTU',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2014,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2014-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2014-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2014',
#             'Value': '2.3 [1.5-3.4]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_FMLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS05-09',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 11.301072,
#             'Id': 10201390,
#             'IndicatorCode': 'NCD_BMI_MINUS2C',
#             'Low': 1.2731064,
#             'NumericValue': 4.8051443,
#             'ParentLocation': 'Western Pacific',
#             'ParentLocationCode': 'WPR',
#             'SpatialDim': 'FJI',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2004,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2004-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2004-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2004',
#             'Value': '4.8 [1.3-11.3]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_FMLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS10-19',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 1.4660601,
#             'Id': 10201561,
#             'IndicatorCode': 'NCD_BMI_MINUS2C',
#             'Low': 0.51111281,
#             'NumericValue': 0.90862475,
#             'ParentLocation': 'Europe',
#             'ParentLocationCode': 'EUR',
#             'SpatialDim': 'NOR',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 1997,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '1997-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '1997-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '1997',
#             'Value': '0.9 [0.5-1.5]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_BTSX',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS05-09',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 17.517653,
#             'Id': 10201755,
#             'IndicatorCode': 'NCD_BMI_MINUS2C',
#             'Low': 4.2587206,
#             'NumericValue': 9.7502895,
#             'ParentLocation': 'Africa',
#             'ParentLocationCode': 'AFR',
#             'SpatialDim': 'TCD',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2002,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2002-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2002-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2002',
#             'Value': '9.8 [4.3-17.5]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_BTSX',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS05-19',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 12.832448,
#             'Id': 10201852,
#             'IndicatorCode': 'NCD_BMI_MINUS2C',
#             'Low': 5.8191415,
#             'NumericValue': 8.9955285,
#             'ParentLocation': 'Africa',
#             'ParentLocationCode': 'AFR',
#             'SpatialDim': 'ZWE',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 1996,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '1996-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '1996-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '1996',
#             'Value': '9.0 [5.8-12.8]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_FMLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS10-19',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 3.1530116,
#             'Id': 10202033,
#             'IndicatorCode': 'NCD_BMI_MINUS2C',
#             'Low': 0.29568668,
#             'NumericValue': 1.2494931,
#             'ParentLocation': 'Europe',
#             'ParentLocationCode': 'EUR',
#             'SpatialDim': 'GRL',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2003,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2003-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2003-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2003',
#             'Value': '1.2 [0.3-3.2]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_MLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS10-19',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 6.2677145,
#             'Id': 10202088,
#             'IndicatorCode': 'NCD_BMI_MINUS2C',
#             'Low': 1.2123232,
#             'NumericValue': 3.114436,
#             'ParentLocation': 'Europe',
#             'ParentLocationCode': 'EUR',
#             'SpatialDim': 'MDA',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 1991,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '1991-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '1991-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '1991',
#             'Value': '3.1 [1.2-6.3]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_FMLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS10-19',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 22.496332,
#             'Id': 10202361,
#             'IndicatorCode': 'NCD_BMI_MINUS2C',
#             'Low': 18.718535,
#             'NumericValue': 20.592622,
#             'ParentLocation': None,
#             'ParentLocationCode': None,
#             'SpatialDim': 'SEAR',
#             'SpatialDimType': 'REGION',
#             'TimeDim': 1997,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '1997-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '1997-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '1997',
#             'Value': '20.6 [18.7-22.5]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_MLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS05-19',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 9.6453577,
#             'Id': 10202368,
#             'IndicatorCode': 'NCD_BMI_MINUS2C',
#             'Low': 2.609776,
#             'NumericValue': 5.5737007,
#             'ParentLocation': 'Europe',
#             'ParentLocationCode': 'EUR',
#             'SpatialDim': 'TKM',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2021,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2021-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2021-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2021',
#             'Value': '5.6 [2.6-9.6]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_MLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS05-19',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 2.1134404,
#             'Id': 10202662,
#             'IndicatorCode': 'NCD_BMI_MINUS2C',
#             'Low': 0.85039204,
#             'NumericValue': 1.3954207,
#             'ParentLocation': 'Europe',
#             'ParentLocationCode': 'EUR',
#             'SpatialDim': 'ITA',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 1998,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '1998-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '1998-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '1998',
#             'Value': '1.4 [0.9-2.1]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_FMLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS10-19',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 6.9543697,
#             'Id': 10202759,
#             'IndicatorCode': 'NCD_BMI_MINUS2C',
#             'Low': 2.5982378,
#             'NumericValue': 4.4881973,
#             'ParentLocation': 'Africa',
#             'ParentLocationCode': 'AFR',
#             'SpatialDim': 'CIV',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 1996,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '1996-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '1996-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '1996',
#             'Value': '4.5 [2.6-7.0]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_BTSX',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS05-19',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 3.1992324,
#             'Id': 10202881,
#             'IndicatorCode': 'NCD_BMI_MINUS2C',
#             'Low': 0.97558582,
#             'NumericValue': 1.8727673,
#             'ParentLocation': 'Europe',
#             'ParentLocationCode': 'EUR',
#             'SpatialDim': 'MLT',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 1991,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '1991-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '1991-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '1991',
#             'Value': '1.9 [1.0-3.2]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_MLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS10-19',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 4.6744592,
#             'Id': 10202934,
#             'IndicatorCode': 'NCD_BMI_MINUS2C',
#             'Low': 1.9308938,
#             'NumericValue': 3.1364918,
#             'ParentLocation': 'Europe',
#             'ParentLocationCode': 'EUR',
#             'SpatialDim': 'SVK',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 1990,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '1990-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '1990-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '1990',
#             'Value': '3.1 [1.9-4.7]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_MLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS05-09',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 14.862186,
#             'Id': 10203148,
#             'IndicatorCode': 'NCD_BMI_MINUS2C',
#             'Low': 1.6658451,
#             'NumericValue': 6.5041237,
#             'ParentLocation': 'Africa',
#             'ParentLocationCode': 'AFR',
#             'SpatialDim': 'BEN',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2018,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2018-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2018-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2018',
#             'Value': '6.5 [1.7-14.9]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_BTSX',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS05-09',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 9.9275246,
#             'Id': 10203289,
#             'IndicatorCode': 'NCD_BMI_MINUS2C',
#             'Low': 1.3006641,
#             'NumericValue': 4.3846358,
#             'ParentLocation': 'Africa',
#             'ParentLocationCode': 'AFR',
#             'SpatialDim': 'COM',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2021,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2021-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2021-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2021',
#             'Value': '4.4 [1.3-9.9]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_MLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS05-19',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 6.1896995,
#             'Id': 10203488,
#             'IndicatorCode': 'NCD_BMI_MINUS2C',
#             'Low': 0.59309802,
#             'NumericValue': 2.4579208,
#             'ParentLocation': 'Western Pacific',
#             'ParentLocationCode': 'WPR',
#             'SpatialDim': 'TUV',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 1995,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '1995-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '1995-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '1995',
#             'Value': '2.5 [0.6-6.2]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_FMLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS05-09',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 3.6881126,
#             'Id': 10203978,
#             'IndicatorCode': 'NCD_BMI_MINUS2C',
#             'Low': 1.9535882,
#             'NumericValue': 2.7351798,
#             'ParentLocation': 'Europe',
#             'ParentLocationCode': 'EUR',
#             'SpatialDim': 'SVK',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2010,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2010-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2010-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2010',
#             'Value': '2.7 [2.0-3.7]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_MLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS10-19',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 17.748718,
#             'Id': 10203990,
#             'IndicatorCode': 'NCD_BMI_MINUS2C',
#             'Low': 10.945857,
#             'NumericValue': 14.256303,
#             'ParentLocation': 'Western Pacific',
#             'ParentLocationCode': 'WPR',
#             'SpatialDim': 'PHL',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 1996,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '1996-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '1996-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '1996',
#             'Value': '14.3 [10.9-17.7]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_MLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS05-19',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 47.339529,
#             'Id': 10204383,
#             'IndicatorCode': 'NCD_BMI_MINUS2C',
#             'Low': 41.089034,
#             'NumericValue': 44.154733,
#             'ParentLocation': 'South-East Asia',
#             'ParentLocationCode': 'SEAR',
#             'SpatialDim': 'IND',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 1992,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '1992-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '1992-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '1992',
#             'Value': '44.2 [41.1-47.3]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_FMLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS05-09',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 1.5261492,
#             'Id': 10204405,
#             'IndicatorCode': 'NCD_BMI_MINUS2C',
#             'Low': 0.67034988,
#             'NumericValue': 1.0428303,
#             'ParentLocation': 'Americas',
#             'ParentLocationCode': 'AMR',
#             'SpatialDim': 'GTM',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2016,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2016-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2016-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2016',
# ...
#             'Dim3Type': None,
#             'High': 12.504472,
#             'Id': 10228941,
#             'IndicatorCode': 'NCD_BMI_MINUS2C',
#             'Low': 9.940405,
#             'NumericValue': 11.198985,
#             'ParentLocation': None,
#             'ParentLocationCode': None,
#             'SpatialDim': 'EMR',
#             'SpatialDimType': 'REGION',
#             'TimeDim': 2020,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2020-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2020-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2020',
#             'Value': '11.2 [9.9-12.5]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_MLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS05-19',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 2.1186823,
#             'Id': 10228976,
#             'IndicatorCode': 'NCD_BMI_MINUS2C',
#             'Low': 0.51774355,
#             'NumericValue': 1.1395036,
#             'ParentLocation': 'Americas',
#             'ParentLocationCode': 'AMR',
#             'SpatialDim': 'CHL',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2017,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2017-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2017-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2017',
#             'Value': '1.1 [0.5-2.1]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_FMLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS05-09',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 1.2343325,
#             'Id': 10229068,
#             'IndicatorCode': 'NCD_BMI_MINUS2C',
#             'Low': 0.39526103,
#             'NumericValue': 0.73658987,
#             'ParentLocation': 'Europe',
#             'ParentLocationCode': 'EUR',
#             'SpatialDim': 'NLD',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2015,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2015-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2015-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2015',
#             'Value': '0.7 [0.4-1.2]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_BTSX',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS05-09',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 6.837184,
#             'Id': 10229167,
#             'IndicatorCode': 'NCD_BMI_MINUS2C',
#             'Low': 4.5423165,
#             'NumericValue': 5.6193952,
#             'ParentLocation': 'Europe',
#             'ParentLocationCode': 'EUR',
#             'SpatialDim': 'ROU',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2021,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2021-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2021-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2021',
#             'Value': '5.6 [4.5-6.8]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_FMLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS10-19',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 5.7143446,
#             'Id': 10229184,
#             'IndicatorCode': 'NCD_BMI_MINUS2C',
#             'Low': 2.7954988,
#             'NumericValue': 4.1406929,
#             'ParentLocation': 'Americas',
#             'ParentLocationCode': 'AMR',
#             'SpatialDim': 'HTI',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2013,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2013-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2013-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2013',
#             'Value': '4.1 [2.8-5.7]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_FMLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS10-19',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 16.427803,
#             'Id': 10230017,
#             'IndicatorCode': 'NCD_BMI_MINUS2C',
#             'Low': 2.4270529,
#             'NumericValue': 7.7241264,
#             'ParentLocation': 'Africa',
#             'ParentLocationCode': 'AFR',
#             'SpatialDim': 'GNQ',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 1991,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '1991-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '1991-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '1991',
#             'Value': '7.7 [2.4-16.4]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_BTSX',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS10-19',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 10.218395,
#             'Id': 10230197,
#             'IndicatorCode': 'NCD_BMI_MINUS2C',
#             'Low': 5.4281726,
#             'NumericValue': 7.5749859,
#             'ParentLocation': 'Europe',
#             'ParentLocationCode': 'EUR',
#             'SpatialDim': 'TJK',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2018,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2018-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2018-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2018',
#             'Value': '7.6 [5.4-10.2]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_BTSX',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS10-19',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 3.5070606,
#             'Id': 10230333,
#             'IndicatorCode': 'NCD_BMI_MINUS2C',
#             'Low': 0.62172064,
#             'NumericValue': 1.7036451,
#             'ParentLocation': 'Western Pacific',
#             'ParentLocationCode': 'WPR',
#             'SpatialDim': 'PNG',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2016,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2016-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2016-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2016',
#             'Value': '1.7 [0.6-3.5]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_FMLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS05-19',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 2.3113417,
#             'Id': 10230483,
#             'IndicatorCode': 'NCD_BMI_MINUS2C',
#             'Low': 0.17322241,
#             'NumericValue': 0.83039319,
#             'ParentLocation': 'Western Pacific',
#             'ParentLocationCode': 'WPR',
#             'SpatialDim': 'COK',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 1991,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '1991-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '1991-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '1991',
#             'Value': '0.8 [0.2-2.3]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_BTSX',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS05-09',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 5.5311758,
#             'Id': 10230567,
#             'IndicatorCode': 'NCD_BMI_MINUS2C',
#             'Low': 0.83201658,
#             'NumericValue': 2.5547672,
#             'ParentLocation': 'Americas',
#             'ParentLocationCode': 'AMR',
#             'SpatialDim': 'ATG',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2011,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2011-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2011-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2011',
#             'Value': '2.6 [0.8-5.5]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_FMLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS05-09',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 4.8802994,
#             'Id': 10230672,
#             'IndicatorCode': 'NCD_BMI_MINUS2C',
#             'Low': 0.2695611,
#             'NumericValue': 1.6012261,
#             'ParentLocation': 'Western Pacific',
#             'ParentLocationCode': 'WPR',
#             'SpatialDim': 'PYF',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2000,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2000-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2000-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2000',
#             'Value': '1.6 [0.3-4.9]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_MLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS05-19',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 17.570008,
#             'Id': 10231030,
#             'IndicatorCode': 'NCD_BMI_MINUS2C',
#             'Low': 15.579873,
#             'NumericValue': 16.556437,
#             'ParentLocation': None,
#             'ParentLocationCode': None,
#             'SpatialDim': 'GLOBAL',
#             'SpatialDimType': 'GLOBAL',
#             'TimeDim': 1993,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '1993-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '1993-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '1993',
#             'Value': '16.6 [15.6-17.6]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_FMLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS05-09',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 3.9618865,
#             'Id': 10231155,
#             'IndicatorCode': 'NCD_BMI_MINUS2C',
#             'Low': 0.1054975,
#             'NumericValue': 1.1168558,
#             'ParentLocation': 'Western Pacific',
#             'ParentLocationCode': 'WPR',
#             'SpatialDim': 'PNG',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2009,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2009-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2009-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2009',
#             'Value': '1.1 [0.1-4.0]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_FMLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS05-09',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 2.8101757,
#             'Id': 10231479,
#             'IndicatorCode': 'NCD_BMI_MINUS2C',
#             'Low': 0.064152246,
#             'NumericValue': 0.73406608,
#             'ParentLocation': 'Western Pacific',
#             'ParentLocationCode': 'WPR',
#             'SpatialDim': 'WSM',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2020,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2020-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2020-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2020',
#             'Value': '0.7 [0.1-2.8]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_MLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS05-19',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 15.325613,
#             'Id': 10232422,
#             'IndicatorCode': 'NCD_BMI_MINUS2C',
#             'Low': 11.349835,
#             'NumericValue': 13.282701,
#             'ParentLocation': 'Western Pacific',
#             'ParentLocationCode': 'WPR',
#             'SpatialDim': 'IDN',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 1999,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '1999-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '1999-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '1999',
#             'Value': '13.3 [11.3-15.3]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_FMLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS10-19',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 5.0678167,
#             'Id': 10232494,
#             'IndicatorCode': 'NCD_BMI_MINUS2C',
#             'Low': 2.6512664,
#             'NumericValue': 3.76525,
#             'ParentLocation': 'Africa',
#             'ParentLocationCode': 'AFR',
#             'SpatialDim': 'MWI',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2003,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2003-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2003-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2003',
#             'Value': '3.8 [2.7-5.1]'},
#            {'Comments': None,
#             'DataSourceDim': None,
#             'DataSourceDimType': None,
#             'Date': '2024-02-29T16:06:41.017+01:00',
#             'Dim1': 'SEX_MLE',
#             'Dim1Type': 'SEX',
#             'Dim2': 'AGEGROUP_YEARS10-19',
#             'Dim2Type': 'AGEGROUP',
#             'Dim3': None,
#             'Dim3Type': None,
#             'High': 7.3074833,
#             'Id': 10232616,
#             'IndicatorCode': 'NCD_BMI_MINUS2C',
#             'Low': 0.46517085,
#             'NumericValue': 2.5427854,
#             'ParentLocation': 'Europe',
#             'ParentLocationCode': 'EUR',
#             'SpatialDim': 'ISL',
#             'SpatialDimType': 'COUNTRY',
#             'TimeDim': 2018,
#             'TimeDimType': 'YEAR',
#             'TimeDimensionBegin': '2018-01-01T00:00:00+01:00',
#             'TimeDimensionEnd': '2018-12-31T00:00:00+01:00',
#             'TimeDimensionValue': '2018',
#             'Value': '2.5 [0.5-7.3]'}]}
# <Response [200]>

# %%
import pandas as pd
malnutrition2=[]
malnutrition2=data.json()["value"]
df_malnutrition2=pd.DataFrame(malnutrition2)
df_malnutrition2
# Out:
#             Id    IndicatorCode SpatialDimType SpatialDim ParentLocationCode  \
# 0      9413261  NCD_BMI_MINUS2C        COUNTRY        CIV                AFR
# 1      9413286  NCD_BMI_MINUS2C        COUNTRY        PRK               SEAR
# 2      9413513  NCD_BMI_MINUS2C        COUNTRY        KHM                WPR
# 3      9413696  NCD_BMI_MINUS2C         REGION        EUR               None
# 4      9413726  NCD_BMI_MINUS2C        COUNTRY        NLD                EUR
# ...        ...              ...            ...        ...                ...
# 62365  9413004  NCD_BMI_MINUS2C        COUNTRY        OMN                EMR
# 62366  9413027  NCD_BMI_MINUS2C        COUNTRY        CHN                WPR
# 62367  9413078  NCD_BMI_MINUS2C        COUNTRY        TKL                WPR
# 62368  9413109  NCD_BMI_MINUS2C        COUNTRY        PNG                WPR
# 62369  9413132  NCD_BMI_MINUS2C        COUNTRY        AUS                WPR
#
#       TimeDimType         ParentLocation Dim1Type      Dim1  TimeDim  ...  \
# 0            YEAR                 Africa      SEX  SEX_BTSX     1999  ...
# 1            YEAR        South-East Asia      SEX  SEX_BTSX     2016  ...
# 2            YEAR        Western Pacific      SEX  SEX_FMLE     2007  ...
# 3            YEAR                   None      SEX  SEX_BTSX     2021  ...
# 4            YEAR                 Europe      SEX   SEX_MLE     1990  ...
# ...           ...                    ...      ...       ...      ...  ...
# 62365        YEAR  Eastern Mediterranean      SEX  SEX_FMLE     2014  ...
# 62366        YEAR        Western Pacific      SEX   SEX_MLE     1993  ...
# 62367        YEAR        Western Pacific      SEX  SEX_FMLE     2003  ...
# 62368        YEAR        Western Pacific      SEX  SEX_FMLE     2000  ...
# 62369        YEAR        Western Pacific      SEX  SEX_FMLE     1999  ...
#
#       DataSourceDim           Value NumericValue       Low       High  \
# 0              None  9.0 [5.9-12.6]     8.995772  5.853993  12.588693
# 1              None  9.9 [4.6-16.9]     9.912948  4.582696  16.918728
# 2              None   7.0 [5.3-9.0]     6.986515  5.261281   8.980648
# 3              None   2.7 [2.4-3.1]     2.705231  2.379007   3.089370
# 4              None   1.0 [0.4-2.0]     1.013980  0.436988   1.985108
# ...             ...             ...          ...       ...        ...
# 62365          None  7.7 [3.1-14.3]     7.658575  3.133570  14.256157
# 62366          None   7.7 [6.7-8.9]     7.714380  6.675442   8.868389
# 62367          None   0.9 [0.1-3.4]     0.931191  0.085426   3.439430
# 62368          None   1.3 [0.1-4.5]     1.261651  0.121650   4.540224
# 62369          None   1.0 [0.7-1.4]     0.999103  0.673372   1.401703
#
#       Comments                           Date  TimeDimensionValue  \
# 0         None  2024-02-29T16:06:41.017+01:00                1999
# 1         None  2024-02-29T16:06:41.017+01:00                2016
# 2         None  2024-02-29T16:06:41.017+01:00                2007
# 3         None    2024-05-23T13:28:38.2+02:00                2021
# 4         None  2024-02-29T16:06:41.017+01:00                1990
# ...        ...                            ...                 ...
# 62365     None  2024-02-29T16:06:41.017+01:00                2014
# 62366     None  2024-02-29T16:06:41.017+01:00                1993
# 62367     None  2024-02-29T16:06:41.017+01:00                2003
# 62368     None  2024-02-29T16:06:41.017+01:00                2000
# 62369     None  2024-02-29T16:06:41.017+01:00                1999
#
#               TimeDimensionBegin           TimeDimensionEnd
# 0      1999-01-01T00:00:00+01:00  1999-12-31T00:00:00+01:00
# 1      2016-01-01T00:00:00+01:00  2016-12-31T00:00:00+01:00
# 2      2007-01-01T00:00:00+01:00  2007-12-31T00:00:00+01:00
# 3      2021-01-01T00:00:00+01:00  2021-12-31T00:00:00+01:00
# 4      1990-01-01T00:00:00+01:00  1990-12-31T00:00:00+01:00
# ...                          ...                        ...
# 62365  2014-01-01T00:00:00+01:00  2014-12-31T00:00:00+01:00
# 62366  1993-01-01T00:00:00+01:00  1993-12-31T00:00:00+01:00
# 62367  2003-01-01T00:00:00+01:00  2003-12-31T00:00:00+01:00
# 62368  2000-01-01T00:00:00+01:00  2000-12-31T00:00:00+01:00
# 62369  1999-01-01T00:00:00+01:00  1999-12-31T00:00:00+01:00
#
# [62370 rows x 25 columns]

# %%
df_obesity.columns
# Out:
# Index(['Id', 'IndicatorCode', 'SpatialDimType', 'SpatialDim', 'TimeDimType',
#        'ParentLocationCode', 'ParentLocation', 'Dim1Type', 'TimeDim', 'Dim1',
#        'Dim2Type', 'Dim2', 'Dim3Type', 'Dim3', 'DataSourceDimType',
#        'DataSourceDim', 'Value', 'NumericValue', 'Low', 'High', 'Comments',
#        'Date', 'TimeDimensionValue', 'TimeDimensionBegin', 'TimeDimensionEnd'],
#       dtype='object')

# %%
import pandas as pd

df_obesity.to_csv("obesity.csv", index=False)
df_obesity2.to_csv("obesity2.csv", index=False)
df_malnutrition.to_csv("malnutrition.csv", index=False)
df_malnutrition2.to_csv("malnutrition2.csv", index=False)

# %%
import pandas as pd

obesity_adults = pd.read_csv("/content/obesity.csv")
obesity_children = pd.read_csv("/content/obesity2.csv")

malnutrition_adults = pd.read_csv("/content/malnutrition.csv")
malnutrition_children = pd.read_csv("/content/malnutrition2.csv")

# %%
obesity_adults["age_group"] = "Adults"
obesity_children["age_group"] = "Children"
malnutrition_adults["age_group"] = "Adults"
malnutrition_children["age_group"] = "Children"
df_obesity = pd.concat(
    [obesity_adults, obesity_children],
    ignore_index=True
)
df_malnutrition = pd.concat(
    [malnutrition_adults, malnutrition_children],
    ignore_index=True
)

df_obesity = df_obesity[
    (df_obesity["TimeDim"] >= 2012) &
    (df_obesity["TimeDim"] <= 2022)
]

df_malnutrition = df_malnutrition[
    (df_malnutrition["TimeDim"] >= 2012) &
    (df_malnutrition["TimeDim"] <= 2022)
]

# %%
df_obesity.head()
df_malnutrition.head()

#df_obesity["age_group"].value_counts()
#df_malnutrition["age_group"].value_counts()
# Out:
#          Id IndicatorCode SpatialDimType SpatialDim ParentLocationCode  \
# 5   9416307   NCD_BMI_18C        COUNTRY        AFG                EMR
# 7   9419094   NCD_BMI_18C        COUNTRY        MYS                WPR
# 9   9420646   NCD_BMI_18C        COUNTRY        BGD               SEAR
# 11  9421519   NCD_BMI_18C        COUNTRY        STP                AFR
# 13  9421971   NCD_BMI_18C        COUNTRY        NZL                WPR
#
#    TimeDimType         ParentLocation Dim1Type  TimeDim      Dim1  ...  \
# 5         YEAR  Eastern Mediterranean      SEX     2015  SEX_FMLE  ...
# 7         YEAR        Western Pacific      SEX     2021  SEX_FMLE  ...
# 9         YEAR        South-East Asia      SEX     2017  SEX_BTSX  ...
# 11        YEAR                 Africa      SEX     2014  SEX_BTSX  ...
# 13        YEAR        Western Pacific      SEX     2014  SEX_FMLE  ...
#
#                Value NumericValue        Low       High  Comments  \
# 5    10.3 [8.0-12.8]    10.270760   8.006914  12.832764       NaN
# 7      5.0 [3.7-6.6]     5.030612   3.692593   6.631450       NaN
# 9   17.4 [15.9-18.8]    17.370060  15.895735  18.846819       NaN
# 11     6.4 [5.2-7.8]     6.448887   5.212862   7.778929       NaN
# 13     1.7 [1.5-2.0]     1.728691   1.478985   2.009351       NaN
#
#                              Date TimeDimensionValue  \
# 5   2024-02-29T16:06:41.017+01:00               2015
# 7   2024-02-29T16:06:41.017+01:00               2021
# 9   2024-02-29T16:06:41.017+01:00               2017
# 11  2024-02-29T16:06:41.017+01:00               2014
# 13  2024-02-29T16:06:41.017+01:00               2014
#
#            TimeDimensionBegin           TimeDimensionEnd  age_group
# 5   2015-01-01T00:00:00+01:00  2015-12-31T00:00:00+01:00     Adults
# 7   2021-01-01T00:00:00+01:00  2021-12-31T00:00:00+01:00     Adults
# 9   2017-01-01T00:00:00+01:00  2017-12-31T00:00:00+01:00     Adults
# 11  2014-01-01T00:00:00+01:00  2014-12-31T00:00:00+01:00     Adults
# 13  2014-01-01T00:00:00+01:00  2014-12-31T00:00:00+01:00     Adults
#
# [5 rows x 26 columns]

# %%
columns_to_keep = [
    "ParentLocation",
    "Dim1",
    "TimeDim",
    "Low",
    "High",
    "NumericValue",
    "SpatialDim",
    "age_group"
]

df_obesity = df_obesity[columns_to_keep]
df_malnutrition = df_malnutrition[columns_to_keep]

rename_columns = {
    "TimeDim": "Year",
    "Dim1": "Gender",
    "NumericValue": "Mean_Estimate",
    "Low": "LowerBound",
    "High": "UpperBound",
    "ParentLocation": "Region",
    "SpatialDim": "Country"
}

df_obesity.rename(columns=rename_columns, inplace=True)
df_malnutrition.rename(columns=rename_columns, inplace=True)

# %%
df_obesity.columns
# Out:
# Index(['Region', 'Gender', 'Year', 'LowerBound', 'UpperBound', 'Mean_Estimate',
#        'Country', 'age_group'],
#       dtype='object')

# %%
df_malnutrition.columns
# Out:
# Index(['Region', 'Gender', 'Year', 'LowerBound', 'UpperBound', 'Mean_Estimate',
#        'Country', 'age_group'],
#       dtype='object')

# %%
def standardize_gender(value):
    if value is None:
        return value
    value = value.lower()
    if "male" in value:
        return "Male"
    elif "female" in value:
        return "Female"
    else:
        return "Both"

df_obesity["Gender"] = df_obesity["Gender"].apply(standardize_gender)
df_malnutrition["Gender"] = df_malnutrition["Gender"].apply(standardize_gender)

# %%
df_obesity.head()
df_malnutrition.head()
# Out:
#                    Region Gender  Year  LowerBound  UpperBound  Mean_Estimate  \
# 5   Eastern Mediterranean   Both  2015    8.006914   12.832764      10.270760
# 7         Western Pacific   Both  2021    3.692593    6.631450       5.030612
# 9         South-East Asia   Both  2017   15.895735   18.846819      17.370060
# 11                 Africa   Both  2014    5.212862    7.778929       6.448887
# 13        Western Pacific   Both  2014    1.478985    2.009351       1.728691
#
#    Country age_group
# 5      AFG    Adults
# 7      MYS    Adults
# 9      BGD    Adults
# 11     STP    Adults
# 13     NZL    Adults

# %%
# !pip install pycountry
# Out:
# Collecting pycountry
#   Downloading pycountry-24.6.1-py3-none-any.whl.metadata (12 kB)
# Downloading pycountry-24.6.1-py3-none-any.whl (6.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 42.0 MB/s eta 0:00:00
# Installing collected packages: pycountry
# Successfully installed pycountry-24.6.1

# %%
import pycountry

# %%
def alpha3_to_country_name(code):
    try:
        country = pycountry.countries.get(alpha_3=code)
        if country:
            return country.name
        else:
            return None
    except:
        return None

# %%
df_obesity["Country"] = df_obesity["Country"].apply(alpha3_to_country_name)
df_malnutrition["Country"] = df_malnutrition["Country"].apply(alpha3_to_country_name)

# %%
special_cases = {
    'GLOBAL': 'Global',
    'WB_LMI': 'Low & Middle Income',
    'WB_HI': 'High Income',
    'WB_LI': 'Low Income',
    'EMR': 'Eastern Mediterranean Region',
    'EUR': 'Europe',
    'AFR': 'Africa',
    'SEAR': 'South-East Asia Region',
    'WPR': 'Western Pacific Region',
    'AMR': 'Americas Region',
    'WB_UMI': 'Upper Middle Income'
}

# %%
def convert_country(code):
    if code in special_cases:
        return special_cases[code]
    try:
        country = pycountry.countries.get(alpha_3=code)
        if country:
            return country.name
    except:
        pass
    return code

# %%
df_obesity["Country"] = df_obesity["Country"].apply(convert_country)
df_malnutrition["Country"] = df_malnutrition["Country"].apply(convert_country)

# %%
df_obesity["Country"].unique()[:20]
df_malnutrition["Country"].unique()[:20]
# Out:
# array(['Afghanistan', 'Malaysia', 'Bangladesh', 'Sao Tome and Principe',
#        'New Zealand', 'Niue', 'Burkina Faso', 'Tajikistan', 'Armenia',
#        'Somalia', 'Eswatini', 'Morocco', 'El Salvador', 'Guinea',
#        'Gambia', 'Bolivia, Plurinational State of', 'South Sudan',
#        'Sierra Leone', 'Belize', 'Zambia'], dtype=object)

# %%
df_obesity.columns
# Out:
# Index(['Region', 'Gender', 'Year', 'LowerBound', 'UpperBound', 'Mean_Estimate',
#        'Country', 'age_group'],
#       dtype='object')

# %%
df_obesity["Age_Group"] = df_obesity["Mean_Estimate"].apply(
    lambda x: "Adult" if x >= 18 else "Child/Adolescent"
)

# %%
df_obesity["CI_Width"] = df_obesity["UpperBound"] - df_obesity["LowerBound"]
df_malnutrition["CI_Width"] = df_malnutrition["UpperBound"] - df_malnutrition["LowerBound"]

# %%
def obesity_category(value):
    if value >= 30:
        return "High"
    elif value >= 25:
        return "Moderate"
    else:
        return "Low"
df_obesity["Obesity_Level"] = df_obesity["Mean_Estimate"].apply(obesity_category)

# %%
def malnutrition_category(value):
    if value >= 20:
        return "High"
    elif value >= 10:
        return "Moderate"
    else:
        return "Low"
df_malnutrition["Malnutrition_Level"] = df_malnutrition["Mean_Estimate"].apply(malnutrition_category)

# %%
df_obesity.drop(columns=["age_group"], inplace=True)
df_malnutrition.drop(columns=["age_group"], inplace=True)

# %%
df_obesity.columns
# Out:
# Index(['Region', 'Gender', 'Year', 'LowerBound', 'UpperBound', 'Mean_Estimate',
#        'Country', 'Age_Group', 'CI_Width', 'Obesity_Level'],
#       dtype='object')

# %%
df_malnutrition.columns
# Out:
# Index(['Region', 'Gender', 'Year', 'LowerBound', 'UpperBound', 'Mean_Estimate',
#        'Country', 'CI_Width', 'Malnutrition_Level'],
#       dtype='object')

# %%
df_obesity.shape
df_malnutrition.shape
# Out:
# (27720, 9)

# %%
df_obesity.info()
df_malnutrition.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 27720 entries, 0 to 83159
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Region         26268 non-null  object
#  1   Gender         27720 non-null  object
#  2   Year           27720 non-null  int64
#  3   LowerBound     27720 non-null  float64
#  4   UpperBound     27720 non-null  float64
#  5   Mean_Estimate  27720 non-null  float64
#  6   Country        26268 non-null  object
#  7   Age_Group      27720 non-null  object
#  8   CI_Width       27720 non-null  float64
#  9   Obesity_Level  27720 non-null  object
# dtypes: float64(4), int64(1), object(5)
# memory usage: 2.3+ MB
# <class 'pandas.core.frame.DataFrame'>
# Index: 27720 entries, 5 to 83155
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Region              26268 non-null  object
#  1   Gender              27720 non-null  object
#  2   Year                27720 non-null  int64
#  3   LowerBound          27720 non-null  float64
#  4   UpperBound          27720 non-null  float64
#  5   Mean_Estimate       27720 non-null  float64
#  6   Country             26268 non-null  object
#  7   CI_Width            27720 non-null  float64
#  8   Malnutrition_Level  27720 non-null  object
# dtypes: float64(4), int64(1), object(4)
# memory usage: 2.1+ MB

# %%
df_obesity.isnull().sum()
df_malnutrition.isnull().sum()
# Out:
# Region                1452
# Gender                   0
# Year                     0
# LowerBound               0
# UpperBound               0
# Mean_Estimate            0
# Country               1452
# CI_Width                 0
# Malnutrition_Level       0
# dtype: int64

# %%
df_obesity.fillna({
    "Region": "Not Available",
    "Country": "Not Available"
}, inplace=True)

df_malnutrition.fillna({
    "Region": "Not Available",
    "Country": "Not Available"
}, inplace=True)

# %%
df_obesity.isnull().sum()
df_malnutrition.isnull().sum()
# Out:
# Region                0
# Gender                0
# Year                  0
# LowerBound            0
# UpperBound            0
# Mean_Estimate         0
# Country               0
# CI_Width              0
# Malnutrition_Level    0
# dtype: int64

# %%
df_obesity.describe()
df_malnutrition.describe()
# Out:
#                Year    LowerBound    UpperBound  Mean_Estimate      CI_Width
# count  27720.000000  27720.000000  27720.000000   27720.000000  27720.000000
# mean    2017.000000      3.397094      8.147889       5.354451      4.750795
# std        3.162335      3.908061      6.443692       4.811220      4.257683
# min     2012.000000      0.023703      0.354833       0.175309      0.166679
# 25%     2014.000000      1.053666      3.143307       2.039278      1.603222
# 50%     2017.000000      1.907971      6.095557       3.597794      3.351093
# 75%     2020.000000      4.186440     11.526301       7.335245      6.530869
# max     2022.000000     31.365401     43.680286      35.894114     26.701744

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(df_obesity["Mean_Estimate"], bins=30, kde=True)
plt.title("Distribution of Obesity Mean Estimate")
plt.show()

# %%
print("Obesity Mean_Estimate Skewness:", df_obesity["Mean_Estimate"].skew())
print("Obesity Mean_Estimate Kurtosis:", df_obesity["Mean_Estimate"].kurtosis())
print("\nMalnutrition Mean_Estimate Skewness:", df_malnutrition["Mean_Estimate"].skew())
print("Malnutrition Mean_Estimate Kurtosis:", df_malnutrition["Mean_Estimate"].kurtosis())
# Out:
# Obesity Mean_Estimate Skewness: 1.856668157575365
# Obesity Mean_Estimate Kurtosis: 5.270543327158809
#
# Malnutrition Mean_Estimate Skewness: 1.799026580818987
# Malnutrition Mean_Estimate Kurtosis: 3.8314992783530233

# %%
sns.histplot(df_malnutrition["Mean_Estimate"], bins=30, kde=True)
plt.title("Distribution of Malnutrition Mean Estimate")
plt.show()

# %%
sns.boxplot(x=df_obesity["CI_Width"])
plt.title("CI Width Distribution – Obesity")
plt.show()

# %%
sns.boxplot(x=df_malnutrition["CI_Width"])
plt.title("CI Width Distribution – Malnutrition")
plt.show()

# %%
obesity_trend = df_obesity.groupby("Year")["Mean_Estimate"].mean()

plt.plot(obesity_trend.index, obesity_trend.values)
plt.title("Average Obesity Trend Over Time")
plt.xlabel("Year")
plt.ylabel("Mean Estimate")
plt.show()

# %%
malnutrition_trend = df_malnutrition.groupby("Year")["Mean_Estimate"].mean()

plt.plot(malnutrition_trend.index, malnutrition_trend.values)
plt.title("Average Malnutrition Trend Over Time")
plt.xlabel("Year")
plt.ylabel("Mean Estimate")
plt.show()

# %%
region_obesity = (
    df_obesity.groupby("Region")["Mean_Estimate"]
    .mean()
    .sort_values(ascending=False)
    .head(10)
)

region_obesity.plot(kind="bar")
plt.title("Top Regions by Obesity Levels")
plt.ylabel("Mean Estimate")
plt.show()

# %%
region_malnutrition = (
    df_malnutrition.groupby("Region")["Mean_Estimate"]
    .mean()
    .sort_values(ascending=False)
    .head(10)
)

region_malnutrition.plot(kind="bar")
plt.title("Top Regions by Malnutrition Levels")
plt.ylabel("Mean Estimate")
plt.show()

# %%
sns.boxplot(
    data=df_obesity,
    x="Region",
    y="Mean_Estimate"
)
plt.xticks(rotation=90)
plt.title("Obesity Variability by Region")
plt.show()

# %%
plt.figure(figsize=(8,4))

sns.kdeplot(df_obesity["Mean_Estimate"], label="Obesity")
sns.kdeplot(df_malnutrition["Mean_Estimate"], label="Malnutrition")

plt.title("Obesity vs Malnutrition Distribution")
plt.legend()
plt.show()

# %%
sns.scatterplot(
    data=df_obesity,
    x="CI_Width",
    y="Mean_Estimate",
    hue="Gender"
)
plt.title("CI Width vs Mean Estimate (Obesity)")
plt.show()

# %%
pivot = df_obesity.pivot_table(
    values="Mean_Estimate",
    index="Region",
    columns="Year",
    aggfunc="mean"
)

sns.heatmap(pivot, cmap="coolwarm")
plt.title("Obesity Heatmap by Region & Year")
plt.show()

# %%
import sqlite3

# Create / connect to database
conn = sqlite3.connect("health_data.db")

# %%
cursor = conn.cursor()

# %%
cursor.execute("""
CREATE TABLE IF NOT EXISTS obesity (
    Year INTEGER,
    Gender TEXT,
    Mean_Estimate REAL,
    LowerBound REAL,
    UpperBound REAL,
    Age_Group TEXT,
    Country TEXT,
    Region TEXT,
    CI_Width REAL,
    Obesity_Level TEXT
)
""")

# %%
cursor.execute("""
CREATE TABLE IF NOT EXISTS malnutrition (
    Year INTEGER,
    Gender TEXT,
    Mean_Estimate REAL,
    LowerBound REAL,
    UpperBound REAL,
    Age_Group TEXT,
    Country TEXT,
    Region TEXT,
    CI_Width REAL,
    Malnutrition_Level TEXT
)
""")

# %%
for _, row in df_obesity.iterrows():
    cursor.execute("""
    INSERT INTO obesity VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?)
    """, (
        row["Year"],
        row["Gender"],
        row["Mean_Estimate"],
        row["LowerBound"],
        row["UpperBound"],
        row["Age_Group"],
        row["Country"],
        row["Region"],
        row["CI_Width"],
        row["Obesity_Level"]
    ))

# %%
df_malnutrition["Age_Group"] = df_malnutrition["Mean_Estimate"].apply(lambda x: "Adult" if x >= 18 else "Child/Adolescent")
for _, row in df_malnutrition.iterrows():
    cursor.execute("""
    INSERT INTO malnutrition VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?)
    """, (
        row["Year"],
        row["Gender"],
        row["Mean_Estimate"],
        row["LowerBound"],
        row["UpperBound"],
        row["Age_Group"],
        row["Country"],
        row["Region"],
        row["CI_Width"],
        row["Malnutrition_Level"]
    ))

# %%
conn.commit()
conn.close()

# %%
conn = sqlite3.connect("health_data.db")
pd.read_sql("SELECT COUNT(*) FROM obesity", conn)
# Out:
#    COUNT(*)
# 0     27720

# %%
pd.read_sql("SELECT COUNT(*) FROM malnutrition", conn)
# Out:
#    COUNT(*)
# 0     27720

# %%
pd.read_sql("SELECT * FROM obesity LIMIT 5", conn)
# Out:
#    Year Gender  Mean_Estimate  LowerBound  UpperBound         Age_Group  \
# 0  2013   Both      58.917272   55.144393   62.697655             Adult
# 1  2017   Both      26.692086   22.315124   31.259042             Adult
# 2  2014   Both       3.958217    3.519309    4.494559  Child/Adolescent
# 3  2016   Both      29.005083   26.754028   31.271335             Adult
# 4  2022   Both      28.981933   23.170659   35.420430             Adult
#
#          Country           Region   CI_Width Obesity_Level
# 0         Tuvalu  Western Pacific   7.553262          High
# 1        Uruguay         Americas   8.943918      Moderate
# 2  Not Available    Not Available   0.975250           Low
# 3    Saint Lucia         Americas   4.517307      Moderate
# 4       Suriname         Americas  12.249771      Moderate

# %%
df_obesity.columns
# Out:
# Index(['Region', 'Gender', 'Year', 'LowerBound', 'UpperBound', 'Mean_Estimate',
#        'Country', 'Age_Group', 'CI_Width', 'Obesity_Level'],
#       dtype='object')

# %%
df_obesity.to_csv("Obesity.csv", index=False)
df_malnutrition.to_csv("Malnutrition.csv", index=False)

# %%
top_5_regions = (
    df_obesity[df_obesity["Year"] == 2022]
    .groupby("Region")["Mean_Estimate"]
    .mean()
    .sort_values(ascending=False)
    .head(5)
)

print(top_5_regions)
# Out:
# Region
# Western Pacific          22.639636
# Americas                 21.213601
# Eastern Mediterranean    18.126910
# Europe                   12.987338
# Not Available            11.462648
# Name: Mean_Estimate, dtype: float64

# %%
query = """
SELECT
    Region,
    AVG(Mean_Estimate) AS avg_obesity
FROM obesity
WHERE Year = 2022
GROUP BY Region
ORDER BY avg_obesity DESC
LIMIT 5;
"""

top_5_regions = pd.read_sql(query, conn)
print(top_5_regions)
# Out:
#                   Region  avg_obesity
# 0        Western Pacific    22.639636
# 1               Americas    21.213601
# 2  Eastern Mediterranean    18.126910
# 3                 Europe    12.987338
# 4          Not Available    11.462648

# %%
query = """
SELECT
    Country,
    MAX(Mean_Estimate) AS mean_estimate
FROM obesity
WHERE Year = 2022
GROUP BY Country
ORDER BY mean_estimate DESC
LIMIT 5;
"""
top_5_country = pd.read_sql(query, conn)
print(top_5_country)
# Out:
#           Country  mean_estimate
# 0  American Samoa      80.609250
# 1           Tonga      79.053253
# 2           Samoa      72.615880
# 3         Tokelau      72.486657
# 4    Cook Islands      71.513951

# %%
df_obesity.isnull().sum()
# Out:
# Region           0
# Gender           0
# Year             0
# LowerBound       0
# UpperBound       0
# Mean_Estimate    0
# Country          0
# Age_Group        0
# CI_Width         0
# Obesity_Level    0
# dtype: int64

# %%
df_obesity
# Out:
#                       Region Gender  Year  LowerBound  UpperBound  \
# 0            Western Pacific   Both  2013   55.144393   62.697655
# 1                   Americas   Both  2017   22.315124   31.259042
# 3              Not Available   Both  2014    3.519309    4.494559
# 7                   Americas   Both  2016   26.754028   31.271335
# 8                   Americas   Both  2022   23.170659   35.420430
# ...                      ...    ...   ...         ...         ...
# 83150        Western Pacific   Both  2017    3.635952    6.089803
# 83151                 Europe   Both  2017   11.444159   14.727987
# 83152  Eastern Mediterranean   Both  2017   11.531880   26.834223
# 83158  Eastern Mediterranean   Both  2014   11.322826   22.882026
# 83159  Eastern Mediterranean   Both  2018   10.011661   19.877386
#
#        Mean_Estimate        Country         Age_Group   CI_Width Obesity_Level
# 0          58.917272         Tuvalu             Adult   7.553262          High
# 1          26.692086        Uruguay             Adult   8.943918      Moderate
# 3           3.958217  Not Available  Child/Adolescent   0.975250           Low
# 7          29.005083    Saint Lucia             Adult   4.517307      Moderate
# 8          28.981933       Suriname             Adult  12.249771      Moderate
# ...              ...            ...               ...        ...           ...
# 83150       4.755271      Indonesia  Child/Adolescent   2.453851           Low
# 83151      13.037372         Greece  Child/Adolescent   3.283828           Low
# 83152      18.621750           Iraq             Adult  15.302343           Low
# 83158      16.665152        Bahrain  Child/Adolescent  11.559200           Low
# 83159      14.687933         Jordan  Child/Adolescent   9.865725           Low
#
# [27720 rows x 10 columns]

# %%
df_malnutrition
# Out:
#                       Region Gender  Year  LowerBound  UpperBound  \
# 5      Eastern Mediterranean   Both  2015    8.006914   12.832764
# 7            Western Pacific   Both  2021    3.692593    6.631450
# 9            South-East Asia   Both  2017   15.895735   18.846819
# 11                    Africa   Both  2014    5.212862    7.778929
# 13           Western Pacific   Both  2014    1.478985    2.009351
# ...                      ...    ...   ...         ...         ...
# 83138                 Europe   Both  2018    2.453300    4.166520
# 83146               Americas   Both  2013    4.440077    7.045904
# 83153                 Africa   Both  2013    3.688974   21.095783
# 83154        Western Pacific   Both  2019    8.558694   11.818832
# 83155  Eastern Mediterranean   Both  2014    3.133570   14.256157
#
#        Mean_Estimate                Country   CI_Width Malnutrition_Level  \
# 5          10.270760            Afghanistan   4.825850           Moderate
# 7           5.030612               Malaysia   2.938857                Low
# 9          17.370060             Bangladesh   2.951084           Moderate
# 11          6.448887  Sao Tome and Principe   2.566067                Low
# 13          1.728691            New Zealand   0.530366                Low
# ...              ...                    ...        ...                ...
# 83138       3.228280               Slovakia   1.713219                Low
# 83146       5.670481                   Cuba   2.605826                Low
# 83153      10.705529                Eritrea  17.406809           Moderate
# 83154      10.138386            Philippines   3.260138           Moderate
# 83155       7.658575                   Oman  11.122587                Low
#
#               Age_Group
# 5      Child/Adolescent
# 7      Child/Adolescent
# 9      Child/Adolescent
# 11     Child/Adolescent
# 13     Child/Adolescent
# ...                 ...
# 83138  Child/Adolescent
# 83146  Child/Adolescent
# 83153  Child/Adolescent
# 83154  Child/Adolescent
# 83155  Child/Adolescent
#
# [27720 rows x 10 columns]
